# %%
import json
import pickle

wikidata_mid_to_fn_dict = pickle.load(open('data/wikidata_mid_to_fn_dict.pickle', 'rb'))
data = json.load(open('data/processed_spice_data/dev_each_type_5.json', 'r'))

# %%
def sub_mid_to_fn(expression):
    seg_list = expression.split()
    for i in range(len(seg_list)):
        token = seg_list[i].strip(')(')
        if token.startswith('P') or token.startswith('Q'):
            fn = wikidata_mid_to_fn_dict.get(token, "unknown_entity")
            seg_list[i] = seg_list[i].replace(token, fn)
    new_expression = ' '.join(seg_list)
    return new_expression

def extract_kg_elements(expression):
    entities, relations, types = set(), set(), set()
    token_list = [seg.strip(')(') for seg in expression.split()]
    for i, token in enumerate(token_list):
        if token.startswith('Q'):
            if token_list[i - 1] != 'P31':
                entity = wikidata_mid_to_fn_dict.get(token, token)
                entities.add(entity)
            else:
                typ = wikidata_mid_to_fn_dict.get(token, token)
                types.add(typ)
        elif token.startswith('P'):
            relation = wikidata_mid_to_fn_dict.get(token, token)
            relations.add(relation)
    return sorted(entities), sorted(relations), sorted(types)

# %%
for qa in data:
    qa['entities'], qa['relations'], qa['types'] = extract_kg_elements(qa['s_expression'])
sorted_data = sorted([{key: qa[key] for key in ('question', 's_expression', 's_expression_cores', 'entities')} for qa in data], key=lambda x: len(x['entities']), reverse=True)
for qa in sorted_data:
    qa['s_expression'] = sub_mid_to_fn(qa['s_expression'])
    qa['s_expression_cores'] = [sub_mid_to_fn(core) for core in qa['s_expression_cores']]
prompt_data = sorted_data[5::10][:10]
test_data = sorted_data[10::10][:10]
print(json.dumps(prompt_data, indent=2))
# Out:
# [
#   {
#     "question": "Which administrative territories have diplomatic relationships with approximately 1 political territory ? [SEP] Georgia, Belarus, Luxembourg [SEP] Do Ukrainka have diplomatic relations with those administrative territories ? [CTX]",
#     "s_expression": "(ALL (IS_TRUE Ukrainka diplomatic_relation Georgia) (IS_TRUE Ukrainka diplomatic_relation Belarus) (IS_TRUE Ukrainka diplomatic_relation Luxembourg))",
#     "s_expression_cores": [
#       "(IS_TRUE Ukrainka diplomatic_relation Georgia)",
#       "(IS_TRUE Ukrainka diplomatic_relation Belarus)",
#       "(IS_TRUE Ukrainka diplomatic_relation Luxembourg)"
#     ],
#     "entities": [
#       "Belarus",
#       "Georgia",
#       "Luxembourg",
#       "Ukrainka"
#     ]
#   },
#   {
#     "question": "Is Anglic languages a portion of Oru\u00e7 Reis-class submarine and West Germanic languages ? [CTX]",
#     "s_expression": "(ALL (IS_TRUE Oru\u00e7_Reis-class_submarine part_of Anglic_languages) (IS_TRUE West_Germanic_languages part_of Anglic_languages))",
#     "s_expression_cores": [
#       "(IS_TRUE Oru\u00e7_Reis-class_submarine part_of Anglic_languages)",
#       "(IS_TRUE West_Germanic_languages part_of Anglic_languages)"
#     ],
#     "entities": [
#       "Anglic_languages",
#       "Oru\u00e7_Reis-class_submarine",
#       "West_Germanic_languages"
#     ]
#   },
#   {
#     "question": "Which administrative territory was Gary Collier born at ? [SEP] Fort Worth [SEP] Is that administrative territory a sister city of Adamsville, New Brunswick and Yuen Long Kau Hui ? [CTX]",
#     "s_expression": "(ALL (IS_TRUE Adamsville,_New_Brunswick twinned_administrative_body Fort_Worth) (IS_TRUE Yuen_Long_Kau_Hui twinned_administrative_body Fort_Worth))",
#     "s_expression_cores": [
#       "(IS_TRUE Adamsville,_New_Brunswick twinned_administrative_body Fort_Worth)",
#       "(IS_TRUE Yuen_Long_Kau_Hui twinned_administrative_body Fort_Worth)"
#     ],
#     "entities": [
#       "Adamsville,_New_Brunswick",
#       "Fort_Worth",
#       "Yuen_Long_Kau_Hui"
#     ]
#   },
#   {
#     "question": "Which people were born at Santa Cruz and have the gender as male ? [CTX]",
#     "s_expression": "(AND (JOIN place_of_birth Santa_Cruz) (JOIN instance_of common_name) (JOIN sex_or_gender male))",
#     "s_expression_cores": [
#       "(AND (JOIN place_of_birth Santa_Cruz) (JOIN instance_of common_name) (JOIN sex_or_gender male))"
#     ],
#     "entities": [
#       "Santa_Cruz",
#       "male"
#     ]
#   },
#   {
#     "question": "Which administrative territories are the native countriesof Willem Caspar de Jonge or are bordered by Altomonte ? [CTX]",
#     "s_expression": "(OR (AND (JOIN (R country_of_citizenship) Willem_Caspar_de_Jonge) (JOIN instance_of designation_for_an_administrative_territorial_entity)) (AND (JOIN (R shares_border_with) Altomonte) (JOIN instance_of designation_for_an_administrative_territorial_entity)))",
#     "s_expression_cores": [
#       "(AND (JOIN (R country_of_citizenship) Willem_Caspar_de_Jonge) (JOIN instance_of designation_for_an_administrative_territorial_entity))",
#       "(AND (JOIN (R shares_border_with) Altomonte) (JOIN instance_of designation_for_an_administrative_territorial_entity))"
#     ],
#     "entities": [
#       "Altomonte",
#       "Willem_Caspar_de_Jonge"
#     ]
#   },
#   {
#     "question": "Was Pascal Greggory born at Hazarat Ali ? [CTX]",
#     "s_expression": "(ALL (IS_TRUE Pascal_Greggory place_of_birth Hazarat_Ali))",
#     "s_expression_cores": [
#       "(IS_TRUE Pascal_Greggory place_of_birth Hazarat_Ali)"
#     ],
#     "entities": [
#       "Hazarat_Ali",
#       "Pascal_Greggory"
#     ]
#   },
#   {
#     "question": "Which people are involved in playing association football and badminton ? [CTX]",
#     "s_expression": "(AND (JOIN sport association_football) (JOIN instance_of common_name) (JOIN sport badminton))",
#     "s_expression_cores": [
#       "(AND (JOIN sport association_football) (JOIN instance_of common_name) (JOIN sport badminton))"
#     ],
#     "entities": [
#       "association_football",
#       "badminton"
#     ]
#   },
#   {
#     "question": "Which sex does Nancy Kemp-Arendt possess ? [SEP] female [SEP] And also Mayumi Tsuchiya [SEP] female [SEP] Does Anni Albers have the gender as that sex ? [CTX]",
#     "s_expression": "(ALL (IS_TRUE Anni_Albers sex_or_gender female))",
#     "s_expression_cores": [
#       "(IS_TRUE Anni_Albers sex_or_gender female)"
#     ],
#     "entities": [
#       "Anni_Albers",
#       "female"
#     ]
#   },
#   {
#     "question": "Which party does Jane Kennedy belong to ? [SEP] Labour Party [SEP] Which ideologies are the political ideologies of that one ? [SEP] democratic socialism, social democracy [SEP] Or Palestine Liberation Front? [CTX]",
#     "s_expression": "(OR (AND (JOIN (R political_ideology) Labour_Party) (JOIN instance_of ideology)) (AND (JOIN (R political_ideology) Palestine_Liberation_Front) (JOIN instance_of ideology)))",
#     "s_expression_cores": [
#       "(AND (JOIN (R political_ideology) Labour_Party) (JOIN instance_of ideology))",
#       "(AND (JOIN (R political_ideology) Palestine_Liberation_Front) (JOIN instance_of ideology))"
#     ],
#     "entities": [
#       "Labour_Party",
#       "Palestine_Liberation_Front"
#     ]
#   },
#   {
#     "question": "Which administrative territories holds diplomatic relationship with Germany and are not the countries of citizenship of Kerem G\u00f6rsev ? [CTX]",
#     "s_expression": "(DIFF (AND (JOIN (R diplomatic_relation) Germany) (JOIN instance_of designation_for_an_administrative_territorial_entity)) (JOIN (R country_of_citizenship) Kerem_G\u00f6rsev))",
#     "s_expression_cores": [
#       "(AND (JOIN (R diplomatic_relation) Germany) (JOIN instance_of designation_for_an_administrative_territorial_entity))",
#       "(JOIN (R country_of_citizenship) Kerem_G\u00f6rsev)"
#     ],
#     "entities": [
#       "Germany",
#       "Kerem_G\u00f6rsev"
#     ]
#   }
# ]

# %%
examples = []
for qa in prompt_data:
    examples.append({'role': 'user', 'content': qa['question']})
    examples.append({'role': 'assistant', 'content': '\u001F'.join(qa['entities'])})
examples
# Out:
# [{'role': 'user',
#   'content': 'Which administrative territories have diplomatic relationships with approximately 1 political territory ? [SEP] Georgia, Belarus, Luxembourg [SEP] Do Ukrainka have diplomatic relations with those administrative territories ? [CTX]'},
#  {'role': 'assistant',
#   'content': 'Belarus\x1fGeorgia\x1fLuxembourg\x1fUkrainka'},
#  {'role': 'user',
#   'content': 'Is Anglic languages a portion of Oruç Reis-class submarine and West Germanic languages ? [CTX]'},
#  {'role': 'assistant',
#   'content': 'Anglic_languages\x1fOruç_Reis-class_submarine\x1fWest_Germanic_languages'},
#  {'role': 'user',
#   'content': 'Which administrative territory was Gary Collier born at ? [SEP] Fort Worth [SEP] Is that administrative territory a sister city of Adamsville, New Brunswick and Yuen Long Kau Hui ? [CTX]'},
#  {'role': 'assistant',
#   'content': 'Adamsville,_New_Brunswick\x1fFort_Worth\x1fYuen_Long_Kau_Hui'},
#  {'role': 'user',
#   'content': 'Which people were born at Santa Cruz and have the gender as male ? [CTX]'},
#  {'role': 'assistant', 'content': 'Santa_Cruz\x1fmale'},
#  {'role': 'user',
#   'content': 'Which administrative territories are the native countriesof Willem Caspar de Jonge or are bordered by Altomonte ? [CTX]'},
#  {'role': 'assistant', 'content': 'Altomonte\x1fWillem_Caspar_de_Jonge'},
#  {'role': 'user',
#   'content': 'Was Pascal Greggory born at Hazarat Ali ? [CTX]'},
#  {'role': 'assistant', 'content': 'Hazarat_Ali\x1fPascal_Greggory'},
#  {'role': 'user',
#   'content': 'Which people are involved in playing association football and badminton ? [CTX]'},
#  {'role': 'assistant', 'content': 'association_football\x1fbadminton'},
#  {'role': 'user',
#   'content': 'Which sex does Nancy Kemp-Arendt possess ? [SEP] female [SEP] And also Mayumi Tsuchiya [SEP] female [SEP] Does Anni Albers have the gender as that sex ? [CTX]'},
#  {'role': 'assistant', 'content': 'Anni_Albers\x1ffemale'},
#  {'role': 'user',
#   'content': 'Which party does Jane Kennedy belong to ? [SEP] Labour Party [SEP] Which ideologies are the political ideologies of that one ? [SEP] democratic socialism, social democracy [SEP] Or Palestine Liberation Front? [CTX]'},
#  {'role': 'assistant',
#   'content': 'Labour_Party\x1fPalestine_Liberation_Front'},
#  {'role': 'user',
#   'content': 'Which administrative territories holds diplomatic relationship with Germany and are not the countries of citizenship of Kerem Görsev ? [CTX]'},
#  {'role': 'assistant', 'content': 'Germany\x1fKerem_Görsev'}]

# %%
import openai
# from time import sleep

temp = 0.3

api_key = 'key'
LLM_engine = 'Qwen/Qwen2.5-32B-Instruct'
openai.base_url = 'http://222.29.156.145:8000/v1/'

# api_key = 'sk-54964e5c3b8c4998a74f7d3e35b618ac'
# LLM_engine = 'deepseek-chat'
# openai.base_url = 'https://api.deepseek.com'

for qa in test_data:
	messages = [{'role': 'system', 'content': 
	"""Perform strict multi-turn dialogue entity extraction:
	- Entities include: person/location/organization names, specialized titles/terms
	- Process ONLY the query after the last [SEP]
	- Resolve all contextual references to preceding entities
	- Output entities joined with \u001F"""}] + examples + [{'role': 'user', 'content': qa['question']}]

	openai.api_key = api_key
	resp = openai.chat.completions.create(
		model=LLM_engine,
		messages=messages,
		temperature=temp,
		max_tokens=256,
		top_p=1,
		frequency_penalty=0,
		presence_penalty=0
	)

	qa['predicted_entities'] = sorted(resp.choices[0].message.content.split('\u001F'))

print(json.dumps(test_data, indent=2))
# Out:
# [
#   {
#     "question": "Which people are in Leroy & Stitch ? [SEP] Dakota Fanning, Chris Sanders, Zoe Caldwell [SEP] Which television programs do those people star in ? [CTX]",
#     "s_expression": "(DISTINCT (AND (JOIN cast_member (VALUES Dakota_Fanning Chris_Sanders Zoe_Caldwell)) (JOIN instance_of television_program)))",
#     "s_expression_cores": [
#       "(AND (JOIN P161 (VALUES Q115541 Q201641 Q1995506)) (JOIN P31 Q15416))"
#     ],
#     "entities": [
#       "Chris_Sanders",
#       "Dakota_Fanning",
#       "Zoe_Caldwell"
#     ],
#     "relations": [
#       "cast_member",
#       "instance_of"
#     ],
#     "types": [
#       "television_program"
#     ],
#     "predicted_entities": [
#       "Chris_Sanders",
#       "Dakota_Fanning",
#       "Leroy_%26_Stitch",
#       "Zoe_Caldwell"
#     ]
#   },
#   {
#     "question": "What do Dolly Parton, Oscar Robertson and Carl Smith do for a living ? [CTX]",
#     "s_expression": "(DISTINCT (AND (JOIN (R occupation) (VALUES Dolly_Parton Oscar_Robertson Carl_Smith)) (JOIN instance_of occupation)))",
#     "s_expression_cores": [
#       "(AND (JOIN (R P106) (VALUES Q180453 Q17717 Q1040657)) (JOIN P31 Q12737077))"
#     ],
#     "entities": [
#       "Carl_Smith",
#       "Dolly_Parton",
#       "Oscar_Robertson"
#     ],
#     "relations": [
#       "instance_of",
#       "occupation"
#     ],
#     "types": [
#       "occupation"
#     ],
#     "predicted_entities": [
#       "Carl_Smith",
#       "Dolly_Parton",
#       "Oscar_Robertson"
#     ]
#   },
#   {
#     "question": "How many nutrients have mitochondrion and cell as their cell component ? [CTX]",
#     "s_expression": "(COUNT (DISTINCT (AND (JOIN cell_component mitochondrion) (JOIN cell_component cell) (JOIN instance_of nutrient))))",
#     "s_expression_cores": [
#       "(AND (JOIN P681 Q39572) (JOIN P681 Q7868) (JOIN P31 Q181394))"
#     ],
#     "entities": [
#       "cell",
#       "mitochondrion"
#     ],
#     "relations": [
#       "cell_component",
#       "instance_of"
#     ],
#     "types": [
#       "nutrient"
#     ],
#     "predicted_entities": [
#       "cell",
#       "mitochondrion"
#     ]
#   },
#   {
#     "question": "Which people were the first persons to come up with ondes Martenot or 912 Maritima ? [CTX]",
#     "s_expression": "(OR (AND (JOIN (R discoverer_or_inventor) ondes_Martenot) (JOIN instance_of common_name)) (AND (JOIN (R discoverer_or_inventor) 912_Maritima) (JOIN instance_of common_name)))",
#     "s_expression_cores": [
#       "(AND (JOIN (R P61) Q862501) (JOIN P31 Q502895))",
#       "(AND (JOIN (R P61) Q157855) (JOIN P31 Q502895))"
#     ],
#     "entities": [
#       "912_Maritima",
#       "ondes_Martenot"
#     ],
#     "relations": [
#       "discoverer_or_inventor",
#       "instance_of"
#     ],
#     "types": [
#       "common_name"
#     ],
#     "predicted_entities": [
#       "912_Maritima",
#       "ondes_Martenot"
#     ]
#   },
#   {
#     "question": "Who starred in Pardonnez-moi ? [SEP] Ma\u00efwenn, Marie-France Pisier, Pascal Greggory [SEP] Who composed that work of art ? [SEP] Mirwais Ahmadza\u00ef [SEP] Which album has been produced by that person ? [SEP] Music [SEP] Was Madonna performed by that album ? [CTX]",
#     "s_expression": "(ALL (IS_TRUE Music performer Madonna))",
#     "s_expression_cores": [
#       "(IS_TRUE Q155358 P175 Q1744)"
#     ],
#     "entities": [
#       "Madonna",
#       "Music"
#     ],
#     "relations": [
#       "performer"
#     ],
#     "types": [],
#     "predicted_entities": [
#       "Madonna",
#       "Marie-France_Pisier",
#       "Ma\u00efwenn",
#       "Music",
#       "Pascal_Greggory"
#     ]
#   },
#   {
#     "question": "Who are associated with the field of occupation association football manager and association football player ? [CTX]",
#     "s_expression": "(DISTINCT (AND (JOIN (R field_of_this_occupation) (VALUES association_football_manager association_football_player)) (JOIN instance_of sport)))",
#     "s_expression_cores": [
#       "(AND (JOIN (R P425) (VALUES Q628099 Q937857)) (JOIN P31 Q349))"
#     ],
#     "entities": [
#       "association_football_manager",
#       "association_football_player"
#     ],
#     "relations": [
#       "field_of_this_occupation",
#       "instance_of"
#     ],
#     "types": [
#       "sport"
#     ],
#     "predicted_entities": [
#       "association-football-manager",
#       "association-football-player"
#     ]
#   },
#   {
#     "question": "Which sports team is Elisa Aguilar a member of ? [SEP] Ros Casares Valencia [SEP] And also tell me about Dick Knostman? [SEP] Philadelphia 76ers [SEP] What did that sports team participate in ? [SEP] basketball [SEP] Does Fabio Mian play that sport ? [CTX]",
#     "s_expression": "(ALL (IS_TRUE Fabio_Mian sport basketball))",
#     "s_expression_cores": [
#       "(IS_TRUE Q3737787 P641 Q5372)"
#     ],
#     "entities": [
#       "Fabio_Mian",
#       "basketball"
#     ],
#     "relations": [
#       "sport"
#     ],
#     "types": [],
#     "predicted_entities": [
#       "Dick_Knostman",
#       "Elisa_Aguilar",
#       "Fabio_Mian",
#       "Philadelphia_76ers",
#       "Ros_Casares_Valencia",
#       "basketball"
#     ]
#   },
#   {
#     "question": "Which sex does Nancy Kemp-Arendt possess ? [SEP] female [SEP] And also Mayumi Tsuchiya [CTX]",
#     "s_expression": "(AND (JOIN (R sex_or_gender) Nancy_Kemp-Arendt) (JOIN instance_of sex) (JOIN (R sex_or_gender) Mayumi_Tsuchiya))",
#     "s_expression_cores": [
#       "(AND (JOIN (R P21) Q1920283) (JOIN P31 Q290) (JOIN (R P21) Q11423301))"
#     ],
#     "entities": [
#       "Mayumi_Tsuchiya",
#       "Nancy_Kemp-Arendt"
#     ],
#     "relations": [
#       "instance_of",
#       "sex_or_gender"
#     ],
#     "types": [
#       "sex"
#     ],
#     "predicted_entities": [
#       "female"
#     ]
#   },
#   {
#     "question": "Which works of art originated in Brazil but not United Kingdom ? [CTX]",
#     "s_expression": "(DIFF (AND (JOIN country_of_origin Brazil) (JOIN instance_of work_of_art)) (JOIN country_of_origin United_Kingdom))",
#     "s_expression_cores": [
#       "(AND (JOIN P495 Q155) (JOIN P31 Q838948))",
#       "(JOIN P495 Q145)"
#     ],
#     "entities": [
#       "Brazil",
#       "United_Kingdom"
#     ],
#     "relations": [
#       "country_of_origin",
#       "instance_of"
#     ],
#     "types": [
#       "work_of_art"
#     ],
#     "predicted_entities": [
#       "Brazil",
#       "United_Kingdom"
#     ]
#   },
#   {
#     "question": "Which male person was the parent of Ludovico II, Marquess of Saluzzo ? [CTX]",
#     "s_expression": "(AND (JOIN (R father) Ludovico_II,_Marquess_of_Saluzzo) (JOIN instance_of common_name))",
#     "s_expression_cores": [
#       "(AND (JOIN (R P22) Q1063295) (JOIN P31 Q502895))"
#     ],
#     "entities": [
#       "Ludovico_II,_Marquess_of_Saluzzo"
#     ],
#     "relations": [
#       "father",
#       "instance_of"
#     ],
#     "types": [
#       "common_name"
#     ],
#     "predicted_entities": [
#       "Ludovico_II,_Marquess_of_Saluzzo",
#       "male"
#     ]
#   }
# ]

# %%
from utils.execute_query import execute_query
from retriever.semantic_retriever import semantic_search

def get_1hop_relations(entity: str):
    query = ("SELECT DISTINCT ?p WHERE { { ?s ?p wd:" + entity + " . } UNION { wd:" + entity + " ?p ?o . } }")
    return execute_query(query)

def get_1hop_types(entity: str):
    query = ("SELECT DISTINCT ?o WHERE { wd:" + entity + " wdt:P31 ?o . }")
    return execute_query(query)

for qa in test_data:
    qa['1hop_relations'] = set()
    qa['1hop_types'] = set()
    for entity in qa['predicted_entities']:
        mid = semantic_search(entity)[0][1]
        qa['1hop_relations'].update([wikidata_mid_to_fn_dict.get(mid, mid) for mid in get_1hop_relations(mid)])
        qa['1hop_types'].update([wikidata_mid_to_fn_dict.get(mid, mid) for mid in get_1hop_types(mid)])
    qa['1hop_relations'] = list(qa['1hop_relations'])
    qa['1hop_types'] = list(qa['1hop_types'])
print(json.dumps(test_data, indent=2))
# Out:
# [
#   {
#     "question": "Which people are in Leroy & Stitch ? [SEP] Dakota Fanning, Chris Sanders, Zoe Caldwell [SEP] Which television programs do those people star in ? [CTX]",
#     "s_expression": "(DISTINCT (AND (JOIN cast_member (VALUES Dakota_Fanning Chris_Sanders Zoe_Caldwell)) (JOIN instance_of television_program)))",
#     "s_expression_cores": [
#       "(AND (JOIN P161 (VALUES Q115541 Q201641 Q1995506)) (JOIN P31 Q15416))"
#     ],
#     "entities": [
#       "Chris_Sanders",
#       "Dakota_Fanning",
#       "Zoe_Caldwell"
#     ],
#     "relations": [
#       "cast_member",
#       "instance_of"
#     ],
#     "types": [
#       "television_program"
#     ],
#     "predicted_entities": [
#       "Chris_Sanders",
#       "Dakota_Fanning",
#       "Leroy_%26_Stitch",
#       "Zoe_Caldwell"
#     ],
#     "1hop_relations": [
#       "MusicBrainz_artist_ID",
#       "producer",
#       "Elonet_person_ID",
#       "family_name",
#       "Scope.dk_person_ID",
#       "instance_of",
#       "occupation",
#       "date_of_birth",
#       "Open_Media_Database_film_ID",
#       "AlloCin\u00e9_person_ID",
#       "production_company",
#       "Danish_National_Filmography_person_ID",
#       "place_of_birth",
#       "height",
#       "Swedish_Film_Database_person_ID",
#       "production_designer",
#       "director",
#       "main_subject",
#       "FAST_ID",
#       "publication_date",
#       "Notable_Names_Database",
#       "WikiTree_person_ID",
#       "award_received",
#       "Commons_category",
#       "OFDb_film_ID",
#       "\u010cSFD_person_ID",
#       "National_Portrait_Gallery_(London)_person_ID",
#       "Facebook_username",
#       "screenwriter",
#       "AllMovie_person_ID",
#       "Freebase_ID",
#       "AllMovie_title_ID",
#       "owned_by",
#       "Kinopoisk_person_ID",
#       "blood_type",
#       "country_of_origin",
#       "contributor_to_the_creative_work_or_subject",
#       "VIAF_cluster_ID",
#       "Netflix_ID",
#       "religion_or_worldview",
#       "NDL_Authority_ID",
#       "color",
#       "KINENOTE_person_ID",
#       "sex_or_gender",
#       "original_language_of_film_or_TV_show",
#       "AlloCin\u00e9_film_ID",
#       "GND_ID",
#       "P1969",
#       "rdf-schema#label",
#       "IMDb_ID",
#       "sister",
#       "Commons_gallery",
#       "Biblioth\u00e8que_nationale_de_France_ID",
#       "nominated_for",
#       "languages_spoken,_written_or_signed",
#       "genre",
#       "Internet_Broadway_Database_person_ID",
#       "educated_at",
#       "voice_actor",
#       "composer",
#       "MovieMeter_film_ID",
#       "storyboard_artist",
#       "Rotten_Tomatoes_ID",
#       "country_of_citizenship",
#       "executive_producer",
#       "residence",
#       "creator",
#       "winner",
#       "Kinopoisk_film_ID",
#       "image",
#       "duration",
#       "ISNI",
#       "original_broadcaster",
#       "National_Library_of_Spain_ID",
#       "given_name",
#       "official_website",
#       "Models.com_person_ID",
#       "title",
#       "PORT_person_ID",
#       "Library_of_Congress_authority_ID",
#       "part_of_the_series",
#       "cast_member",
#       "NLA_Trove_people_ID",
#       "IdRef_ID"
#     ],
#     "1hop_types": [
#       "common_name",
#       "television_program"
#     ]
#   },
#   {
#     "question": "What do Dolly Parton, Oscar Robertson and Carl Smith do for a living ? [CTX]",
#     "s_expression": "(DISTINCT (AND (JOIN (R occupation) (VALUES Dolly_Parton Oscar_Robertson Carl_Smith)) (JOIN instance_of occupation)))",
#     "s_expression_cores": [
#       "(AND (JOIN (R P106) (VALUES Q180453 Q17717 Q1040657)) (JOIN P31 Q12737077))"
#     ],
#     "entities": [
#       "Carl_Smith",
#       "Dolly_Parton",
#       "Oscar_Robertson"
#     ],
#     "relations": [
#       "instance_of",
#       "occupation"
#     ],
#     "types": [
#       "occupation"
#     ],
#     "predicted_entities": [
#       "Carl_Smith",
#       "Dolly_Parton",
#       "Oscar_Robertson"
#     ],
#     "1hop_relations": [
#       "SELIBR_ID",
#       "MusicBrainz_artist_ID",
#       "Elonet_person_ID",
#       "family_name",
#       "Scope.dk_person_ID",
#       "instance_of",
#       "occupation",
#       "date_of_birth",
#       "AlloCin\u00e9_person_ID",
#       "discography",
#       "Danish_National_Filmography_person_ID",
#       "place_of_birth",
#       "CANTIC_ID_(former_scheme)",
#       "Guardian_topic_ID",
#       "NL_CR_AUT_ID",
#       "Basketball_Reference_NBA_player_ID",
#       "Swedish_Film_Database_person_ID",
#       "YouTube_channel_ID",
#       "notable_work",
#       "Libraries_Australia_ID",
#       "FAST_ID",
#       "topic's_main_category",
#       "lyricist",
#       "Notable_Names_Database",
#       "birth_name",
#       "WikiTree_person_ID",
#       "award_received",
#       "Commons_category",
#       "\u010cSFD_person_ID",
#       "Facebook_username",
#       "category's_main_topic",
#       "AllMovie_person_ID",
#       "Freebase_ID",
#       "instrument",
#       "owned_by",
#       "Kinopoisk_person_ID",
#       "record_label",
#       "Open_Library_ID",
#       "participant_in",
#       "VIAF_cluster_ID",
#       "Sports-Reference.com_Olympic_athlete_ID_(archived)",
#       "voice_type",
#       "sex_or_gender",
#       "X_(Twitter)_username",
#       "position_played_on_team_/_speciality",
#       "ethnic_group",
#       "founded_by",
#       "Spotify_artist_ID",
#       "GND_ID",
#       "drafted_by",
#       "NORAF_ID",
#       "performer",
#       "rdf-schema#label",
#       "IMDb_ID",
#       "Commons_gallery",
#       "Biblioth\u00e8que_nationale_de_France_ID",
#       "nominated_for",
#       "work_location",
#       "languages_spoken,_written_or_signed",
#       "genre",
#       "member_of_sports_team",
#       "named_after",
#       "Internet_Broadway_Database_person_ID",
#       "spouse",
#       "sport",
#       "educated_at",
#       "Discogs_artist_ID",
#       "Nationale_Thesaurus_voor_Auteursnamen_ID",
#       "composer",
#       "country_of_citizenship",
#       "residence",
#       "creator",
#       "winner",
#       "AllMusic_artist_ID",
#       "image",
#       "ISNI",
#       "National_Library_of_Spain_ID",
#       "given_name",
#       "official_website",
#       "PORT_person_ID",
#       "godparent",
#       "Library_of_Congress_authority_ID",
#       "cast_member",
#       "IdRef_ID"
#     ],
#     "1hop_types": [
#       "common_name"
#     ]
#   },
#   {
#     "question": "How many nutrients have mitochondrion and cell as their cell component ? [CTX]",
#     "s_expression": "(COUNT (DISTINCT (AND (JOIN cell_component mitochondrion) (JOIN cell_component cell) (JOIN instance_of nutrient))))",
#     "s_expression_cores": [
#       "(AND (JOIN P681 Q39572) (JOIN P681 Q7868) (JOIN P31 Q181394))"
#     ],
#     "entities": [
#       "cell",
#       "mitochondrion"
#     ],
#     "relations": [
#       "cell_component",
#       "instance_of"
#     ],
#     "types": [
#       "nutrient"
#     ],
#     "predicted_entities": [
#       "cell",
#       "mitochondrion"
#     ],
#     "1hop_relations": [
#       "topic's_main_category",
#       "named_after",
#       "has_part(s)_of_the_class",
#       "BNCF_Thesaurus_ID",
#       "NDL_Authority_ID",
#       "instance_of",
#       "PSH_ID",
#       "Commons_category",
#       "Terminologia_Histologica",
#       "described_by_source",
#       "Foundational_Model_of_Anatomy_ID",
#       "has_part(s)",
#       "location",
#       "category's_main_topic",
#       "Gene_Ontology_ID",
#       "image",
#       "subclass_of",
#       "Freebase_ID",
#       "cell_component",
#       "MeSH_descriptor_ID",
#       "GND_ID",
#       "exact_match",
#       "rdf-schema#label",
#       "Commons_gallery",
#       "part_of",
#       "Library_of_Congress_authority_ID"
#     ],
#     "1hop_types": [
#       "part",
#       "physical_object"
#     ]
#   },
#   {
#     "question": "Which people were the first persons to come up with ondes Martenot or 912 Maritima ? [CTX]",
#     "s_expression": "(OR (AND (JOIN (R discoverer_or_inventor) ondes_Martenot) (JOIN instance_of common_name)) (AND (JOIN (R discoverer_or_inventor) 912_Maritima) (JOIN instance_of common_name)))",
#     "s_expression_cores": [
#       "(AND (JOIN (R P61) Q862501) (JOIN P31 Q502895))",
#       "(AND (JOIN (R P61) Q157855) (JOIN P31 Q502895))"
#     ],
#     "entities": [
#       "912_Maritima",
#       "ondes_Martenot"
#     ],
#     "relations": [
#       "discoverer_or_inventor",
#       "instance_of"
#     ],
#     "types": [
#       "common_name"
#     ],
#     "predicted_entities": [
#       "912_Maritima",
#       "ondes_Martenot"
#     ],
#     "1hop_relations": [
#       "orbital_inclination",
#       "argument_of_periapsis",
#       "instance_of",
#       "periapsis",
#       "apoapsis",
#       "mean_anomaly",
#       "provisional_designation",
#       "time_of_discovery_or_invention",
#       "discoverer_or_inventor",
#       "Commons_category",
#       "orbital_eccentricity",
#       "JPL_Small-Body_Database_SPK-ID",
#       "orbital_period",
#       "site_of_astronomical_discovery",
#       "minor_planet_group",
#       "field_of_this_occupation",
#       "subclass_of",
#       "Freebase_ID",
#       "instrument",
#       "absolute_magnitude",
#       "longitude_of_ascending_node",
#       "Gran_Enciclop\u00e8dia_Catalana_ID_(former_scheme)",
#       "semi-major_axis_of_an_orbit",
#       "follows",
#       "Art_&_Architecture_Thesaurus_ID",
#       "MusicBrainz_instrument_ID",
#       "rdf-schema#label",
#       "followed_by"
#     ],
#     "1hop_types": [
#       "musical_instrument",
#       "astronomical_object_type"
#     ]
#   },
#   {
#     "question": "Who starred in Pardonnez-moi ? [SEP] Ma\u00efwenn, Marie-France Pisier, Pascal Greggory [SEP] Who composed that work of art ? [SEP] Mirwais Ahmadza\u00ef [SEP] Which album has been produced by that person ? [SEP] Music [SEP] Was Madonna performed by that album ? [CTX]",
#     "s_expression": "(ALL (IS_TRUE Music performer Madonna))",
#     "s_expression_cores": [
#       "(IS_TRUE Q155358 P175 Q1744)"
#     ],
#     "entities": [
#       "Madonna",
#       "Music"
#     ],
#     "relations": [
#       "performer"
#     ],
#     "types": [],
#     "predicted_entities": [
#       "Madonna",
#       "Marie-France_Pisier",
#       "Ma\u00efwenn",
#       "Music",
#       "Pascal_Greggory"
#     ],
#     "1hop_relations": [
#       "SELIBR_ID",
#       "MusicBrainz_artist_ID",
#       "producer",
#       "field_of_work",
#       "has_use",
#       "Elonet_person_ID",
#       "family_name",
#       "Curlie_ID",
#       "Scope.dk_person_ID",
#       "author",
#       "instance_of",
#       "occupation",
#       "industry",
#       "date_of_birth",
#       "native_language",
#       "AlloCin\u00e9_person_ID",
#       "National_Library_of_Romania_ID",
#       "IPI_name_number",
#       "discography",
#       "KMDb_person_ID",
#       "Instagram_username",
#       "inspired_by",
#       "relative",
#       "Danish_National_Filmography_person_ID",
#       "place_of_birth",
#       "is_a_list_of",
#       "Munzinger_person_ID",
#       "CANTIC_ID_(former_scheme)",
#       "Guardian_topic_ID",
#       "NL_CR_AUT_ID",
#       "Swedish_Film_Database_person_ID",
#       "director",
#       "Perlentaucher_ID",
#       "SoundCloud_ID",
#       "main_subject",
#       "Libraries_Australia_ID",
#       "FAST_ID",
#       "definition_domain",
#       "topic's_main_category",
#       "lyricist",
#       "Notable_Names_Database",
#       "template_has_topic",
#       "birth_name",
#       "Dewey_Decimal_Classification",
#       "fabrication_method",
#       "WikiTree_person_ID",
#       "product,_material,_or_service_produced_or_provided",
#       "award_received",
#       "Commons_category",
#       "\u010cSFD_person_ID",
#       "Facebook_username",
#       "mother",
#       "has_part(s)",
#       "New_York_Times_topic_ID",
#       "category's_main_topic",
#       "screenwriter",
#       "AllMovie_person_ID",
#       "Freebase_ID",
#       "NUKAT_ID",
#       "Flickr_user_ID",
#       "depicts",
#       "instrument",
#       "place_of_death",
#       "BiblioNet_author_ID",
#       "manifestation_of",
#       "Kinopoisk_person_ID",
#       "is_the_study_of",
#       "influenced_by",
#       "Gran_Enciclop\u00e8dia_Catalana_ID_(former_scheme)",
#       "date_of_death",
#       "TCM_Movie_Database_person_ID",
#       "EDb_person_ID",
#       "NLP_ID_(old)",
#       "filmography",
#       "logo_image",
#       "record_label",
#       "SBN_author_ID",
#       "permanent_duplicated_item",
#       "Open_Library_ID",
#       "statement_is_subject_of",
#       "VIAF_cluster_ID",
#       "NDL_Authority_ID",
#       "PSH_ID",
#       "category_combines_topics",
#       "member_of_political_party",
#       "voice_type",
#       "elCinema_person_ID",
#       "CCAB_ID",
#       "KINENOTE_person_ID",
#       "child",
#       "sex_or_gender",
#       "X_(Twitter)_username",
#       "genealogics.org_person_ID",
#       "Google+_ID_(archived)",
#       "icon",
#       "website_account_on",
#       "list_of_works",
#       "Canadiana_Authorities_ID_(former_scheme)",
#       "ethnic_group",
#       "member_of",
#       "NSK_ID",
#       "Portuguese_National_Library_author_ID",
#       "field_of_this_occupation",
#       "elFilm_person_ID",
#       "Spotify_artist_ID",
#       "founded_by",
#       "radio_format",
#       "RSL_ID_(person)",
#       "name_in_native_language",
#       "GND_ID",
#       "NACSIS-CAT_author_ID",
#       "manner_of_death",
#       "P1969",
#       "performer",
#       "Encyclop\u00e6dia_Britannica_Online_ID",
#       "rdf-schema#label",
#       "IMDb_ID",
#       "sister",
#       "Commons_gallery",
#       "Biblioth\u00e8que_nationale_de_France_ID",
#       "topic's_main_Wikimedia_portal",
#       "Genius_artist_ID",
#       "nominated_for",
#       "sexual_orientation",
#       "languages_spoken,_written_or_signed",
#       "genre",
#       "named_after",
#       "Internet_Broadway_Database_person_ID",
#       "spouse",
#       "Filmportal_ID",
#       "educated_at",
#       "BNCF_Thesaurus_ID",
#       "National_Library_of_Israel_ID_(old)",
#       "Discogs_artist_ID",
#       "Nationale_Thesaurus_voor_Auteursnamen_ID",
#       "composer",
#       "significant_event",
#       "CONOR.SI_ID",
#       "Rotten_Tomatoes_ID",
#       "number_of_children",
#       "country_of_citizenship",
#       "executive_producer",
#       "Rock_and_Roll_Hall_of_Fame_ID",
#       "described_by_source",
#       "residence",
#       "winner",
#       "AllMusic_artist_ID",
#       "image",
#       "ISNI",
#       "subclass_of",
#       "Wikimedia_portal's_main_topic",
#       "brother",
#       "TED_topic_ID",
#       "Munzinger_Pop_ID",
#       "National_Library_of_Spain_ID",
#       "given_name",
#       "official_website",
#       "topic's_main_template",
#       "signature",
#       "facet_of",
#       "Encyclop\u00e6dia_Universalis_ID",
#       "PORT_person_ID",
#       "National_Library_of_Latvia_ID",
#       "Universal_Decimal_Classification",
#       "part_of",
#       "director_/_manager",
#       "Library_of_Congress_authority_ID",
#       "cast_member",
#       "NLA_Trove_people_ID",
#       "IdRef_ID",
#       "unmarried_partner"
#     ],
#     "1hop_types": [
#       "common_name",
#       "activity"
#     ]
#   },
#   {
#     "question": "Who are associated with the field of occupation association football manager and association football player ? [CTX]",
#     "s_expression": "(DISTINCT (AND (JOIN (R field_of_this_occupation) (VALUES association_football_manager association_football_player)) (JOIN instance_of sport)))",
#     "s_expression_cores": [
#       "(AND (JOIN (R P425) (VALUES Q628099 Q937857)) (JOIN P31 Q349))"
#     ],
#     "entities": [
#       "association_football_manager",
#       "association_football_player"
#     ],
#     "relations": [
#       "field_of_this_occupation",
#       "instance_of"
#     ],
#     "types": [
#       "sport"
#     ],
#     "predicted_entities": [
#       "association-football-manager",
#       "association-football-player"
#     ],
#     "1hop_relations": [
#       "topic's_main_category",
#       "field_of_work",
#       "sport",
#       "template_has_topic",
#       "instance_of",
#       "occupation",
#       "category_combines_topics",
#       "Commons_category",
#       "male_form_of_label",
#       "category's_main_topic",
#       "equivalent_class",
#       "is_a_list_of",
#       "field_of_this_occupation",
#       "subclass_of",
#       "female_form_of_label",
#       "Freebase_ID",
#       "Wikidata_property",
#       "properties_for_this_type",
#       "topic's_main_template",
#       "GND_ID",
#       "rdf-schema#label",
#       "notable_work",
#       "part_of",
#       "main_subject",
#       "position_held"
#     ],
#     "1hop_types": [
#       "occupation"
#     ]
#   },
#   {
#     "question": "Which sports team is Elisa Aguilar a member of ? [SEP] Ros Casares Valencia [SEP] And also tell me about Dick Knostman? [SEP] Philadelphia 76ers [SEP] What did that sports team participate in ? [SEP] basketball [SEP] Does Fabio Mian play that sport ? [CTX]",
#     "s_expression": "(ALL (IS_TRUE Fabio_Mian sport basketball))",
#     "s_expression_cores": [
#       "(IS_TRUE Q3737787 P641 Q5372)"
#     ],
#     "entities": [
#       "Fabio_Mian",
#       "basketball"
#     ],
#     "relations": [
#       "sport"
#     ],
#     "types": [],
#     "predicted_entities": [
#       "Dick_Knostman",
#       "Elisa_Aguilar",
#       "Fabio_Mian",
#       "Philadelphia_76ers",
#       "Ros_Casares_Valencia",
#       "basketball"
#     ],
#     "1hop_relations": [
#       "genre",
#       "member_of_sports_team",
#       "topic's_main_category",
#       "participant_in",
#       "field_of_work",
#       "sport",
#       "has_use",
#       "family_name",
#       "Sports-Reference.com_Olympic_athlete_ID_(archived)",
#       "BNCF_Thesaurus_ID",
#       "instance_of",
#       "NDL_Authority_ID",
#       "PSH_ID",
#       "occupation",
#       "UNSPSC_Code",
#       "category_combines_topics",
#       "industry",
#       "date_of_birth",
#       "Commons_category",
#       "sex_or_gender",
#       "country_of_citizenship",
#       "Unicode_character",
#       "position_played_on_team_/_speciality",
#       "winner",
#       "mass",
#       "category's_main_topic",
#       "image",
#       "duration",
#       "place_of_birth",
#       "inception",
#       "Great_Aragonese_Encyclopedia_ID",
#       "subclass_of",
#       "field_of_this_occupation",
#       "Wikimedia_portal's_main_topic",
#       "Freebase_ID",
#       "height",
#       "country",
#       "occupant",
#       "Basketball_Reference_NBA_player_ID",
#       "given_name",
#       "official_website",
#       "Gran_Enciclop\u00e8dia_Catalana_ID_(former_scheme)",
#       "GND_ID",
#       "drafted_by",
#       "facet_of",
#       "Art_&_Architecture_Thesaurus_ID",
#       "rdf-schema#label",
#       "Commons_gallery",
#       "main_subject",
#       "topic's_main_Wikimedia_portal",
#       "part_of",
#       "Library_of_Congress_authority_ID",
#       "sports_discipline_competed_in",
#       "New_York_Times_topic_ID",
#       "participant",
#       "languages_spoken,_written_or_signed"
#     ],
#     "1hop_types": [
#       "common_name",
#       "sport",
#       "sports_team"
#     ]
#   },
#   {
#     "question": "Which sex does Nancy Kemp-Arendt possess ? [SEP] female [SEP] And also Mayumi Tsuchiya [CTX]",
#     "s_expression": "(AND (JOIN (R sex_or_gender) Nancy_Kemp-Arendt) (JOIN instance_of sex) (JOIN (R sex_or_gender) Mayumi_Tsuchiya))",
#     "s_expression_cores": [
#       "(AND (JOIN (R P21) Q1920283) (JOIN P31 Q290) (JOIN (R P21) Q11423301))"
#     ],
#     "entities": [
#       "Mayumi_Tsuchiya",
#       "Nancy_Kemp-Arendt"
#     ],
#     "relations": [
#       "instance_of",
#       "sex_or_gender"
#     ],
#     "types": [
#       "sex"
#     ],
#     "predicted_entities": [
#       "female"
#     ],
#     "1hop_relations": [
#       "genre",
#       "named_after",
#       "field_of_work",
#       "different_from",
#       "has_characteristic",
#       "instance_of",
#       "opposite_of",
#       "category_combines_topics",
#       "competition_class",
#       "sex_or_gender",
#       "has_part(s)",
#       "Wikidata_usage_instructions",
#       "image",
#       "is_a_list_of",
#       "subclass_of",
#       "depicts",
#       "used_by",
#       "rdf-schema#label",
#       "main_subject"
#     ],
#     "1hop_types": [
#       "sex"
#     ]
#   },
#   {
#     "question": "Which works of art originated in Brazil but not United Kingdom ? [CTX]",
#     "s_expression": "(DIFF (AND (JOIN country_of_origin Brazil) (JOIN instance_of work_of_art)) (JOIN country_of_origin United_Kingdom))",
#     "s_expression_cores": [
#       "(AND (JOIN P495 Q155) (JOIN P31 Q838948))",
#       "(JOIN P495 Q145)"
#     ],
#     "entities": [
#       "Brazil",
#       "United_Kingdom"
#     ],
#     "relations": [
#       "country_of_origin",
#       "instance_of"
#     ],
#     "types": [
#       "work_of_art"
#     ],
#     "predicted_entities": [
#       "Brazil",
#       "United_Kingdom"
#     ],
#     "1hop_relations": [
#       "field_of_work",
#       "Curlie_ID",
#       "instance_of",
#       "patron_saint",
#       "occupation",
#       "employer",
#       "NUTS_code",
#       "diplomatic_relation",
#       "production_company",
#       "FIPS_10-4_(countries_and_regions)",
#       "population",
#       "head_of_state",
#       "category_for_people_who_died_here",
#       "area",
#       "capital",
#       "place_of_birth",
#       "inception",
#       "coordinates_of_northernmost_point",
#       "basin_country",
#       "trunk_prefix",
#       "Guardian_topic_ID",
#       "country_calling_code",
#       "located_in/on_physical_feature",
#       "narrative_location",
#       "mains_voltage",
#       "public_holiday",
#       "category_of_associated_people",
#       "terminus_location",
#       "aircraft_registration_prefix",
#       "main_subject",
#       "place_of_publication",
#       "Libraries_Australia_ID",
#       "FAST_ID",
#       "topic's_main_category",
#       "basic_form_of_government",
#       "flag",
#       "located_in_time_zone",
#       "coat_of_arms_image",
#       "nominal_GDP",
#       "IOC_country_code",
#       "Dewey_Decimal_Classification",
#       "emergency_phone_number",
#       "signatory",
#       "organizer",
#       "operating_area",
#       "Commons_category",
#       "headquarters_location",
#       "highest_judicial_authority",
#       "contains_the_administrative_territorial_entity",
#       "lowest_point",
#       "operator",
#       "has_part(s)",
#       "Facebook_username",
#       "Nomisma_ID",
#       "represents",
#       "category's_main_topic",
#       "located_in_the_administrative_territorial_entity",
#       "mobile_country_code",
#       "inflation_rate",
#       "allegiance",
#       "Freebase_ID",
#       "depicts",
#       "IPA_transcription",
#       "main_regulatory_text",
#       "place_of_death",
#       "owned_by",
#       "GeoNames_ID",
#       "Gini_coefficient",
#       "locator_map_image",
#       "age_of_majority",
#       "published_in",
#       "OpenStreetMap_relation_ID",
#       "compulsory_education_(minimum_age)",
#       "official_language",
#       "indigenous_to",
#       "country_of_origin",
#       "MusicBrainz_area_ID",
#       "demonym",
#       "ISO_3166-2_code",
#       "GSS_code_(2011)",
#       "record_label",
#       "ISO_3166-1_alpha-3_code",
#       "ISO_3166-1_alpha-2_code",
#       "permanent_duplicated_item",
#       "geography_of_topic",
#       "flag_image",
#       "VIAF_cluster_ID",
#       "driving_side",
#       "continent",
#       "NDL_Authority_ID",
#       "category_combines_topics",
#       "coordinate_location",
#       "category_for_people_buried_here",
#       "motto",
#       "head_of_government",
#       "replaced_by",
#       "page_banner",
#       "top-level_Internet_domain",
#       "history_of_topic",
#       "Human_Development_Index",
#       "location",
#       "ethnic_group",
#       "member_of",
#       "NSK_ID",
#       "separated_from",
#       "location_of_formation",
#       "executive_body",
#       "location_of_creation",
#       "distributed_by",
#       "founded_by",
#       "publisher",
#       "coat_of_arms",
#       "GND_ID",
#       "NACSIS-CAT_author_ID",
#       "applies_to_jurisdiction",
#       "Encyclop\u00e6dia_Britannica_Online_ID",
#       "rdf-schema#label",
#       "legislative_body",
#       "Commons_gallery",
#       "Biblioth\u00e8que_nationale_de_France_ID",
#       "topic's_main_Wikimedia_portal",
#       "office_held_by_head_of_state",
#       "followed_by",
#       "work_location",
#       "official_name",
#       "participant",
#       "total_reserves",
#       "anthem",
#       "named_after",
#       "highest_point",
#       "compulsory_education_(maximum_age)",
#       "port_of_registry",
#       "PPP_GDP_per_capita",
#       "National_Library_of_Israel_ID_(old)",
#       "central_bank",
#       "category_for_people_born_here",
#       "filming_location",
#       "architect",
#       "endemic_to",
#       "office_held_by_head_of_government",
#       "country_of_citizenship",
#       "described_by_source",
#       "residence",
#       "winner",
#       "manufacturer",
#       "authority",
#       "licensed_to_broadcast_to",
#       "image",
#       "ISNI",
#       "shares_border_with",
#       "electrical_plug_type",
#       "country",
#       "capital_of",
#       "Wikimedia_portal's_main_topic",
#       "marriageable_age",
#       "TED_topic_ID",
#       "territory_claimed_by",
#       "unemployment_rate",
#       "National_Library_of_Spain_ID",
#       "official_website",
#       "category_for_films_shot_at_this_location",
#       "facet_of",
#       "follows",
#       "currency",
#       "Universal_Decimal_Classification",
#       "ISO_3166-1_numeric_code",
#       "said_to_be_the_same_as",
#       "part_of",
#       "Library_of_Congress_authority_ID",
#       "New_York_Times_topic_ID",
#       "country_for_sport",
#       "IdRef_ID",
#       "short_name"
#     ],
#     "1hop_types": [
#       "designation_for_an_administrative_territorial_entity"
#     ]
#   },
#   {
#     "question": "Which male person was the parent of Ludovico II, Marquess of Saluzzo ? [CTX]",
#     "s_expression": "(AND (JOIN (R father) Ludovico_II,_Marquess_of_Saluzzo) (JOIN instance_of common_name))",
#     "s_expression_cores": [
#       "(AND (JOIN (R P22) Q1063295) (JOIN P31 Q502895))"
#     ],
#     "entities": [
#       "Ludovico_II,_Marquess_of_Saluzzo"
#     ],
#     "relations": [
#       "father",
#       "instance_of"
#     ],
#     "types": [
#       "common_name"
#     ],
#     "predicted_entities": [
#       "Ludovico_II,_Marquess_of_Saluzzo",
#       "male"
#     ],
#     "1hop_relations": [
#       "INSEE_municipality_code",
#       "spouse",
#       "located_in_time_zone",
#       "dissolved,_abolished_or_demolished_date",
#       "VIAF_cluster_ID",
#       "instance_of",
#       "coordinate_location",
#       "father",
#       "date_of_birth",
#       "child",
#       "replaced_by",
#       "Commons_category",
#       "sex_or_gender",
#       "contains_the_administrative_territorial_entity",
#       "mother",
#       "replaces",
#       "located_in_the_administrative_territorial_entity",
#       "area",
#       "image",
#       "place_of_birth",
#       "shares_border_with",
#       "Freebase_ID",
#       "country",
#       "place_of_death",
#       "GeoNames_ID",
#       "given_name",
#       "locator_map_image",
#       "official_website",
#       "GND_ID",
#       "date_of_death",
#       "postal_code",
#       "rdf-schema#label",
#       "Biblioth\u00e8que_nationale_de_France_ID",
#       "IdRef_ID"
#     ],
#     "1hop_types": [
#       "common_name",
#       "type_of_french_administrative_division"
#     ]
#   }
# ]

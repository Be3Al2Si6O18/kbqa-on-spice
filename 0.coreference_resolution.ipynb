# %%
from openai import OpenAI

client_qwen = OpenAI(
    base_url = 'http://222.29.156.145:8000/v1/',
    api_key = 'key',
    timeout=30
)

client_deepseek = OpenAI(
    base_url="https://api.deepseek.com",
    api_key="sk-54964e5c3b8c4998a74f7d3e35b618ac",
    timeout=60
)

# %%
import json
data = json.load(open('data/processed_spice_data/dev_each_type_50.json', 'r'))
wikidata_mid_to_fn = json.load(open('data/wikidata_mid_to_fn.json', 'r'))

# %%
from retriever.semantic_retriever import SemanticRetriever
entity_retriever = SemanticRetriever('entity')

# %%
from utils.execute_query import execute_query
def get_type(entity_fn):
    entity_mid = entity_retriever.semantic_search(entity_fn.replace(' ', '_'))[0][1]
    result = execute_query(f'SELECT ?x WHERE {{ wd:{entity_mid} wdt:P31 ?x }}')
    types = [wikidata_mid_to_fn[mid] for mid in result]
    return [typ for typ in types if not typ.startswith('Wikimedia')]

# %%
memory = {}
clock = 0
last_question = ''

prompt1 = 'Extract entities from the input text. Entities are unique, distinguishable noun phrases with actual meaning, including: person names, locations, organizations, time points, product names, events, abstract concepts, etc. Exclude pure numbers. Output can be an empty string. Return entities joined by \u001F without any explanatory text.'
prompt2 = '''
You are a coreference resolution system for knowledge graph QA dialogues. Process inputs as follows:

1. Input Specifications:
- Multi-turn dialogues are separated by [SEP]
- Entity list follows [ENTITIES] marker (format: Entity: entity_type)

2. Processing Rules:
A) For multi-turn dialogues:
    a. Extract the last question between the last [SEP] and [ENTITIES] as the target question
    b. Resolve coreferences (pronouns/ellipsis) using preceding context
    c. Generate complete standalone question

B) For single-turn dialogues:
    Preserve the question exactly

Examples:
Input: "When was Google founded? [ENTITIES] Google: organization"
Output: When was Google founded?

Input: "Which sex does Lev Mayorov possess ? [SEP] male [SEP] And also tell me about Pál Jávor? [ENTITIES] Lev Mayorov: common_name; Pál Jávor: common_name"
Output: Which sex does Pál Jávor possess?
                
Input: "Where is Ch\u00e2telperronian located on ? [SEP] Iberian Peninsula [SEP] And also tell me about Qarwarasu (Huancavelica)? [ENTITIES] Ch\u00e2telperronian: concept; Iberian Peninsula: landform; Qarwarasu (Huancavelica): terrain"
Output: Where is Qarwarasu (Huancavelica) located on?
                
Input: "Which people emerged victorious in La Madrid Challenge by La Vuelta 2016 and La Madrid Challenge by La Vuelta 2015 ? [SEP] Giorgia Bronzini, Shelley Olds, Kirsten Wild [SEP] Which television programs are that person a screenwriter of ? [SEP] Did you mean Giorgia Bronzini ? [SEP] No, I meant Shelley Olds. Could you tell me the answer for that? [ENTITIES] La Madrid Challenge by La Vuelta 2016: cycling_race_class_defined_by_the_International_Cycling_Union; La Madrid Challenge by La Vuelta 2015: cycling_race_class_defined_by_the_International_Cycling_Union; Giorgia Bronzini: common_name; Shelley Olds: common_name; Kirsten Wild: common_name"
Output: Which television programs is Shelley Olds a screenwriter of?
'''

for qa in data:
    # extract entities
    clock = (clock + 1) % 10
    question = qa['question'][len(last_question):] if qa['question'].startswith(last_question[:-6]) else qa['question']
    messages = [{'role': 'system', 'content': prompt1}, {'role': 'user', 'content': question}]
    resp = client_qwen.chat.completions.create(
        model='Qwen/Qwen2.5-32B-Instruct',
        messages=messages,
        temperature=0,
        max_tokens=256,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0
    )
    entities = resp.choices[0].message.content.split('\u001F')

    # update memory
    for entity in entities:
        if not entity: continue
        types = memory[entity][0] if entity in memory else get_type(entity)
        if types:
            memory[entity] = (types, clock)

    for entity in list(memory.keys()):
        if memory[entity][1] == (clock + 1) % 10:
            del memory[entity]

    last_question = qa['question']

    # coreference resolution
    question = qa['question'][:-6] + ' [ENTITIES] ' + '; '.join([f'{entity}: {typ}' for entity in memory for typ in memory[entity][0]])
    messages = [{'role': 'system', 'content': prompt2}, {'role': 'user', 'content': question}]
    resp = client_deepseek.chat.completions.create(
        model='deepseek-chat',
        messages=messages,
        temperature=0,
        max_tokens=256,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0
    )
    coreference_resolved_question = resp.choices[0].message.content
    if coreference_resolved_question.startswith('Output: '):
        coreference_resolved_question = coreference_resolved_question[8:]
    qa['coreference_resolved_question'] = coreference_resolved_question
    print(question.rsplit('[ENTITIES]', 1)[0].replace(' [SEP] ', '\n'))
    print()
    print(coreference_resolved_question)
    print()
    print('--------------------')
    print()
# Out:
# Which male person was the parent of Ludovico II, Marquess of Saluzzo ?
#
# Which male person was the parent of Ludovico II, Marquess of Saluzzo?
#
# --------------------
#
# Who are the children of Ludovico II, Marquess of Saluzzo ?
#
# Who are the children of Ludovico II, Marquess of Saluzzo?
#
# --------------------
#
# Who are the children of Ludovico II, Marquess of Saluzzo ?
# Gian Gabriele I of Saluzzo, Francesco of Saluzzo, Giovanni Ludovico, Marquess of Saluzzo
# Who are siblings of that one ?
# Did you mean Francesco of Saluzzo ?
# No, I meant Giovanni Ludovico, Marquess of Saluzzo. Could you tell me the answer for that?
#
# Who are the siblings of Giovanni Ludovico, Marquess of Saluzzo?
#
# --------------------
#
# Who are the children of Ludovico II, Marquess of Saluzzo ?
# Gian Gabriele I of Saluzzo, Francesco of Saluzzo, Giovanni Ludovico, Marquess of Saluzzo
# Who are siblings of that one ?
# Did you mean Francesco of Saluzzo ?
# No, I meant Giovanni Ludovico, Marquess of Saluzzo. Could you tell me the answer for that?
# Francesco of Saluzzo, Gian Gabriele I of Saluzzo, Michele Antonio, Marquess of Saluzzo
# Do Painter of Berlin A 34 have those ones as an offspring ?
#
# Do Painter of Berlin A 34 have Francesco of Saluzzo, Gian Gabriele I of Saluzzo, Michele Antonio, Marquess of Saluzzo as an offspring?
#
# --------------------
#
# How many people have Gian Gabriele I of Saluzzo as their sibling ?
#
# How many people have Gian Gabriele I of Saluzzo as their sibling?
#
# --------------------
#
# How many people have Gian Gabriele I of Saluzzo as their sibling ?
# 3
# And also tell me about Jacob Gerritsz. Cuyp?
#
# How many people have Jacob Gerritsz. Cuyp as their sibling?
#
# --------------------
#
# How many people have Gian Gabriele I of Saluzzo as their sibling ?
# 3
# And also tell me about Jacob Gerritsz. Cuyp?
# 1
# And also tell me about Alice Franklin?
#
# How many people have Alice Franklin as their sibling?
#
# --------------------
#
# How many sexes are the sex of Alice Franklin or Luqman ?
#
# How many sexes are the sex of Alice Franklin or Luqman?
#
# --------------------
#
# How many people have Ludovico I, Marquess of Saluzzo as father ?
#
# How many people have Ludovico I, Marquess of Saluzzo as father?
#
# --------------------
#
# How many people have Ludovico I, Marquess of Saluzzo as father ?
# 1
# Which person has that one as spouse ?
#
# Which person has Gian Gabriele I of Saluzzo as spouse?
#
# --------------------
#
# What was the main subject in the work Lessons of a Dream ?
#
# What was the main subject in the work Lessons of a Dream?
#
# --------------------
#
# What was the main subject in the work Lessons of a Dream ?
# association football
# Where did that sport originate ?
#
# Where did association football originate?
#
# --------------------
#
# Which technicss are used for the production of max number of works of art ?
#
# Which techniques are used for the production of max number of works of art?
#
# --------------------
#
# Which musical ensemble had Chris Broderick as its member ?
#
# Which musical ensemble had Chris Broderick as its member?
#
# --------------------
#
# Which sex does Chris Broderick have ?
#
# Which sex does Chris Broderick have?
#
# --------------------
#
# Which sex does Chris Broderick have ?
# male
# And how about Charles Divine?
#
# Which sex does Charles Divine have?
#
# --------------------
#
# Which location did Megadeth orginate in ?
#
# Which location did Megadeth originate in?
#
# --------------------
#
# Which location did Megadeth orginate in ?
# Los Angeles
# Which book was published in that administrative territory ?
#
# Which book was published in Los Angeles?
#
# --------------------
#
# How many musical ensembles did atmost 1 musical ensembles or people influence ?
#
# How many musical ensembles did atmost 1 musical ensembles or people influence?
#
# --------------------
#
# How many musical ensembles did atmost 1 musical ensembles or people influence ?
# 94
# Which museum released that book ?
#
# Which museum released that book?
#
# (Note: The question appears to be unrelated to the provided entities and context. Coreference resolution was attempted but no clear referent for "that book" could be found in the dialogue history or entity list.)
#
# --------------------
#
# Which works of art have a setting location of Los Angeles and were originally created in English language ?
#
# Which works of art have a setting location of Los Angeles and were originally created in English language?
#
# --------------------
#
# Which works of art have a setting location of Los Angeles and were originally created in English language ?
# Some of them are Pretty Persuasion, 3 Strikes, Psycho Cop 2, Black November, Memento, Last Vegas, Jack's Back, Trackdown, The Terminator, The Italian Job
# Which languages are the original languages of creation of those works of art ?
#
# Which languages are the original languages of creation of Pretty Persuasion, 3 Strikes, Psycho Cop 2, Black November, Memento, Last Vegas, Jack's Back, Trackdown, The Terminator, The Italian Job?
#
# --------------------
#
# Which book represents an edition or translation of English ?
#
# Which book represents an edition or translation of English?
#
# --------------------
#
# Which political territory is the place of death of Lázaro Bardón ?
#
# Which political territory is the place of death of Lázaro Bardón?
#
# --------------------
#
# What are the professions of Lázaro Bardón ?
#
# What are the professions of Lázaro Bardón?
#
# --------------------
#
# Which administrative territory is the native country of Lázaro Bardón ?
#
# Which administrative territory is the native country of Lázaro Bardón?
#
# --------------------
#
# Which administrative territory is the native country of Lázaro Bardón ?
# Spain
# Which sex does that person possess ?
#
# Which sex does Lázaro Bardón possess?
#
# --------------------
#
# Which administrative territory is the native country of Lázaro Bardón ?
# Spain
# Which sex does that person possess ?
# male
# Which sexes do lesser number of people have than that sex ?
#
# Which sexes do lesser number of people have than male?
#
# --------------------
#
# How many administrative territories share the border with Spain ?
#
# How many administrative territories share the border with Spain?
#
# --------------------
#
# How many administrative territories share the border with Spain ?
# 2
# And how about Pozohondo?
#
# How many administrative territories share the border with Pozohondo?
#
# --------------------
#
# How many administrative territories share the border with Spain ?
# 2
# And how about Pozohondo?
# 2
# And what about Bekkevoort?
#
# How many administrative territories share the border with Bekkevoort?
#
# --------------------
#
# Which is the highest peak of Spain ?
#
# Which is the highest peak of Spain?
#
# --------------------
#
# Which administrative territories have min number of legislatures and municipal councils as their representative body ?
#
# Which administrative territories have min number of legislatures and municipal councils as their representative body?
#
# --------------------
#
# Which administrative territories have min number of legislatures and municipal councils as their representative body ?
# Italy, Brazil, Netherlands
# Are Arija known to have diplomatic connections with those administrative territories ?
#
# Are Arija known to have diplomatic connections with Italy, Brazil, Netherlands?
#
# --------------------
#
# Which political territories have tactful political relations with max number of administrative territories ?
#
# Which political territories have tactful political relations with max number of administrative territories?
#
# --------------------
#
# Which sex does Émile Forsanz belong to ?
#
# Which sex does Émile Forsanz belong to?
#
# --------------------
#
# Which administrative territory is the place of death of Émile Forsanz ?
#
# Which administrative territory is the place of death of Émile Forsanz?
#
# --------------------
#
# Which administrative territory is the place of death of Émile Forsanz ?
# Versailles
# Which person is that administrative territory the head of goverment of ?
#
# Which person is Versailles the head of government of?
#
# --------------------
#
# How many Esperanto congresses and statutes are situated at Versailles ?
#
# How many Esperanto congresses and statutes are situated at Versailles?
#
# --------------------
#
# Which applications did max number of people dub for ?
#
# Which applications did max number of people dub for?
#
# --------------------
#
# Has Super Smash Bros. Brawl been dubbed by Félix Rasumny and Hironori Miyata ?
#
# Has Super Smash Bros. Brawl been dubbed by Félix Rasumny and Hironori Miyata?
#
# --------------------
#
# How many french administrative divisions share the border with Versailles ?
#
# How many french administrative divisions share the border with Versailles?
#
# --------------------
#
# How many french administrative divisions share the border with Versailles ?
# 12
# And also tell me about Blaye-les-Mines?
#
# How many french administrative divisions share the border with Blaye-les-Mines?
#
# --------------------
#
# How many french administrative divisions share the border with Versailles ?
# 12
# And also tell me about Blaye-les-Mines?
# 5
# And also tell me about Marsolan?
#
# How many french administrative divisions share the border with Marsolan?
#
# --------------------
#
# How many administrative territories are the narrative locations of atleast 840 applications or works of art ?
#
# How many administrative territories are the narrative locations of atleast 840 applications or works of art?
#
# --------------------
#
# Which works were described in min number of applications ?
#
# Which works were described in min number of applications?
#
# --------------------
#
# What is the sex of Michael Brun ?
#
# What is the sex of Michael Brun?
#
# --------------------
#
# Which division is the record label of Michael Brun ?
#
# Which division is the record label of Michael Brun?
#
# --------------------
#
# Which concept is the genre for Michael Brun ?
#
# Which concept is the genre for Michael Brun?
#
# --------------------
#
# Which administrative territory is the country of citizenship of Michael Brun ?
#
# Which administrative territory is the country of citizenship of Michael Brun?
#
# --------------------
#
# Which administrative territory is the country of citizenship of Michael Brun ?
# Haiti
# And what about Jacob Adriaensz Bellevois?
#
# Which administrative territory is the country of citizenship of Jacob Adriaensz Bellevois?
#
# --------------------
#
# Which administrative territory is the country of citizenship of Michael Brun ?
# Haiti
# And what about Jacob Adriaensz Bellevois?
# Netherlands
# How many administrative territories are the countries of origin of more number of collectables and literary works than that administrative territory ?
#
# How many administrative territories are the countries of origin of more number of collectables and literary works than Netherlands?
#
# --------------------
#
# How many administrative territories have tactful political relations with atmost 63 administrative territories ?
#
# How many administrative territories have tactful political relations with atmost 63 administrative territories?
#
# --------------------
#
# Which administrative territories are the countries of origin of around the same number of literary works or television programs as Bulgaria ?
#
# Which administrative territories are the countries of origin of around the same number of literary works or television programs as Bulgaria?
#
# --------------------
#
# Which administrative territories are the countries of origin of around the same number of literary works or television programs as Bulgaria ?
# Italy, Brazil, Georgia
# And how about Kingdom of the Netherlands?
#
# Which administrative territories are the countries of origin of around the same number of literary works or television programs as Kingdom of the Netherlands?
#
# --------------------
#
# Which concepts do Michael Brun or Ivan Vaughan do for a living ?
#
# Which concepts do Michael Brun or Ivan Vaughan do for a living?
#
# --------------------
#
# How many administrative territories have diplomatic relations with lesser number of administrative territories and political territories than Ethiopia ?
#
# How many administrative territories have diplomatic relations with lesser number of administrative territories and political territories than Ethiopia?
#
# --------------------
#
# How many administrative territories have diplomatic relations with lesser number of administrative territories and political territories than Ethiopia ?
# 71
# And also tell me about South Africa?
#
# How many administrative territories have diplomatic relations with lesser number of administrative territories and political territories than South Africa?
#
# --------------------
#
# How many administrative territories have diplomatic relations with lesser number of administrative territories and political territories than Ethiopia ?
# 71
# And also tell me about South Africa?
# 124
# Which architectural structure was commissioned by that administrative territory ?
#
# Which architectural structure was commissioned by South Africa?
#
# --------------------
#
# What was the noble title held by Willem Caspar de Jonge ?
#
# What was the noble title held by Willem Caspar de Jonge?
#
# --------------------
#
# Where did Willem Caspar de Jonge expire ?
#
# Where did Willem Caspar de Jonge expire?
#
# --------------------
#
# Which political organization is Willem Caspar de Jonge a member of ?
#
# Which political organization is Willem Caspar de Jonge a member of?
#
# --------------------
#
# Which political organizations are a component of min number of political organizations ?
#
# Which political organizations are a component of min number of political organizations?
#
# --------------------
#
# Which administrative territories are the native countriesof Willem Caspar de Jonge or are bordered by Altomonte ?
#
# Which administrative territories are the native countries of Willem Caspar de Jonge or are bordered by Altomonte?
#
# --------------------
#
# Which political territories have ambassadorial relations with less number of administrative territories than Germany ?
#
# Which political territories have ambassadorial relations with less number of administrative territories than Germany?
#
# --------------------
#
# Which political territories have ambassadorial relations with less number of administrative territories than Germany ?
# Australia, Denmark, Canada
# Did those political territories particiate in Scheidler v. National Organization for Women ?
#
# Did Australia, Denmark, and Canada participate in Scheidler v. National Organization for Women?
#
# --------------------
#
# Which administrative territories have diplomatic relationships with approximately 1 political territory ?
#
# Which administrative territories have diplomatic relationships with approximately 1 political territory?
#
# --------------------
#
# Which administrative territories have diplomatic relationships with approximately 1 political territory ?
# Georgia, Belarus, Luxembourg
# Do Ukrainka have diplomatic relations with those administrative territories ?
#
# Does Ukrainka have diplomatic relations with Georgia, Belarus, and Luxembourg?
#
# --------------------
#
# Which administrative territories have diplomatic relationships with greater number of administrative territories than Guinea ?
#
# Which administrative territories have diplomatic relationships with greater number of administrative territories than Guinea?
#
# --------------------
#
# What were awarded to Vladimir von Manstein ?
#
# What were awarded to Vladimir von Manstein?
#
# --------------------
#
# Which military school is Vladimir von Manstein an alumni of ?
#
# Which military school is Vladimir von Manstein an alumni of?
#
# --------------------
#
# How many people are Order of Saint Anna, 4th class named after ?
#
# How many people are Order of Saint Anna, 4th class named after?
#
# --------------------
#
# How many people are Order of Saint Anna, 4th class named after ?
# 1
# And how about 7968 Elst-Pizarro?
#
# How many people are Elst-Pizarro named after?
#
# --------------------
#
# How many people are Order of Saint Anna, 4th class named after ?
# 1
# And how about 7968 Elst-Pizarro?
# 2
# And what about avenue Gustave-V-de-Suède?
#
# How many people are avenue Gustave-V-de-Suède named after?
#
# --------------------
#
# How many people are Order of Saint Anna, 4th class named after ?
# 1
# And how about 7968 Elst-Pizarro?
# 2
# And what about avenue Gustave-V-de-Suède?
# 1
# Which administrative territory is that street located in ?
#
# Which administrative territory is avenue Gustave-V-de-Suède located in?
#
# --------------------
#
# How many people are Order of Saint Anna, 4th class named after ?
# 1
# And how about 7968 Elst-Pizarro?
# 2
# And what about avenue Gustave-V-de-Suède?
# 1
# Which administrative territory is that street located in ?
# France
# Which concepts are located in that administrative territory ?
#
# Which concepts are located in France?
#
# --------------------
#
# Which concepts have less number of educations and human actions as thier field of occupation than antisemit ?
#
# Which concepts have less number of educations and human actions as their field of occupation than antisemit?
#
# --------------------
#
# Which concepts have less number of educations and human actions as thier field of occupation than antisemit ?
# housewife, philosopher, Wikipedian
# And also tell me about drill instructor?
#
# Which concepts have less number of educations and human actions as their field of occupation than drill instructor?
#
# --------------------
#
# What are the job of Lau Kar-leung ?
#
# What are the jobs of Lau Kar-leung?
#
# --------------------
#
# What manner did Lau Kar-leung die ?
#
# What manner did Lau Kar-leung die?
#
# --------------------
#
# How many professions are the subordinates of around the same number of organizations or business organizations as 2K Games ?
#
# How many professions are the subordinates of around the same number of organizations or business organizations as 2K Games?
#
# --------------------
#
# Which professions are greater number of professions the subordinate of than Zynga ?
#
# Which professions are greater number of professions the subordinate of than Zynga?
#
# --------------------
#
# Which professions are the subordinates of approximately the same number of business enterprises or business organizations as Creative Assembly ?
#
# Which professions are the subordinates of approximately the same number of business enterprises or business organizations as Creative Assembly?
#
# --------------------
#
# Which business enterprises contains max number of professions as their subordinate ?
#
# Which business enterprises contains max number of professions as their subordinate?
#
# --------------------
#
# Which business enterprises contains max number of professions as their subordinate ?
# Sega Sammy Holdings, Columbus Nova
# What is the parent organization of that one ?
# Did you mean Sega Sammy Holdings ?
# No, I meant Columbus Nova. Could you tell me the answer for that?
#
# What is the parent organization of Columbus Nova?
#
# --------------------
#
# Which business enterprises contains max number of professions as their subordinate ?
# Sega Sammy Holdings, Columbus Nova
# What is the parent organization of that one ?
# Did you mean Sega Sammy Holdings ?
# No, I meant Columbus Nova. Could you tell me the answer for that?
# Renova Group
# How many business enterprises are that business enterprise a parent organization of ?
#
# How many business enterprises is Renova Group a parent organization of?
#
# --------------------
#
# How many products were produced by id Software or Sun Microsystems ?
#
# How many products were produced by id Software or Sun Microsystems ?
#
# --------------------
#
# How many symbols and organizations are under posessision of Sony Interactive Entertainment ?
#
# How many symbols and organizations are under possession of Sony Interactive Entertainment?
#
# --------------------
#
# Which language is spoken by Carlos Santos ?
#
# Which language is spoken by Carlos Santos?
#
# --------------------
#
# What is the sex of Carlos Santos ?
#
# What is the sex of Carlos Santos?
#
# --------------------
#
# Who starred in Pardonnez-moi ?
#
# Who starred in Pardonnez-moi?
#
# --------------------
#
# Who starred in Pardonnez-moi ?
# Maïwenn, Marie-France Pisier, Pascal Greggory
# Who composed that work of art ?
#
# Who composed Pardonnez-moi?
#
# --------------------
#
# Who starred in Pardonnez-moi ?
# Maïwenn, Marie-France Pisier, Pascal Greggory
# Who composed that work of art ?
# Mirwais Ahmadzaï
# Which album has been produced by that person ?
#
# Which album has been produced by Mirwais Ahmadzaï?
#
# --------------------
#
# Who starred in Pardonnez-moi ?
# Maïwenn, Marie-France Pisier, Pascal Greggory
# Who composed that work of art ?
# Mirwais Ahmadzaï
# Which album has been produced by that person ?
# Music
# Was Madonna performed by that album ?
#
# Was Madonna performed by Music?
#
# --------------------
#
# Was Pascal Greggory born at Hazarat Ali ?
#
# Was Pascal Greggory born at Hazarat Ali?
#
# --------------------
#
# Which administrative territory does Prignano Cilento belong to ?
#
# Which administrative territory does Prignano Cilento belong to?
#
# --------------------
#
# Which administrative territory does Prignano Cilento belong to ?
# Italy
# Which people do that administrative territory serve as the head of government for ?
#
# Which people does Italy serve as the head of government for?
#
# --------------------
#
# Which musical instruments are played by approximately the same number of people as baritone horn ?
#
# Which musical instruments are played by approximately the same number of people as baritone horn?
#
# --------------------
#
# Which musical instruments are played by approximately the same number of people as baritone horn ?
# davul, harpsichord, Wurlitzer electric piano
# And how about morin khuur?
#
# Which musical instruments are played by approximately the same number of people as morin khuur?
#
# --------------------
#
# Which people plays Wurlitzer electric piano and are a male ?
#
# Which people play Wurlitzer electric piano and are male?
#
# --------------------
#
# Which collectables have been dubbed by lesser number of people than Ōkami Kakushi ?
#
# Which collectables have been dubbed by lesser number of people than Ōkami Kakushi?
#
# --------------------
#
# Which collectables have been dubbed by lesser number of people than Ōkami Kakushi ?
# Shakugan no Shana, No Game No Life-mart, Durarara!!
# And also tell me about Ro-Kyu-Bu!?
#
# Which collectables have been dubbed by lesser number of people than Ro-Kyu-Bu?
#
# --------------------
#
# Which person has Shakugan no Shana as a notable work ?
#
# Which person has Shakugan no Shana as a notable work?
#
# --------------------
#
# How many computing platforms or mobile devices are the platforms for which Shakugan no Shana were developed ?
#
# How many computing platforms or mobile devices are the platforms for which Shakugan no Shana were developed?
#
# --------------------
#
# Which people are in Leroy & Stitch ?
#
# Which people are in Leroy & Stitch?
#
# --------------------
#
# Which people are in Leroy & Stitch ?
# Dakota Fanning, Chris Sanders, Zoe Caldwell
# Which television programs do those people star in ?
#
# Which television programs do Dakota Fanning, Chris Sanders, and Zoe Caldwell star in?
#
# --------------------
#
# Which people are in Leroy & Stitch ?
# Dakota Fanning, Chris Sanders, Zoe Caldwell
# Which television programs do those people star in ?
# 3
# Where was that person decalred as a victor ?
# 2
# Yes
#
# Where was Zoe Caldwell declared as a victor?
#
# --------------------
#
# Which administrative territories are the origins of Leroy & Stitch and are Tsuru Aoki an inhabitant of ?
#
# Which administrative territories are the origins of Leroy & Stitch and are Tsuru Aoki an inhabitant of?
#
# --------------------
#
# Which administrative territories are the origins of Leroy & Stitch and are Tsuru Aoki an inhabitant of ?
# United States of America
# Which administrative territories are known as the capital of that administrative territory ?
#
# Which administrative territories are known as the capital of United States of America?
#
# --------------------
#
# Which administrative territories are the origins of Leroy & Stitch and are Tsuru Aoki an inhabitant of ?
# United States of America
# Which administrative territories are known as the capital of that administrative territory ?
# New York City, Washington, D.C.
# Which cities are twin town of those administrative territories ?
#
# Which cities are twin towns of New York City and Washington, D.C.?
#
# --------------------
#
# Which US administrative territory was the place of residence of Dakota Fanning ?
#
# Which US administrative territory was the place of residence of Dakota Fanning?
#
# --------------------
#
# Which US administrative territory was the place of residence of Dakota Fanning ?
# Georgia
# And which administrative territory?
#
# Which US administrative territory was the place of residence of Dakota Fanning?
#
# --------------------
#
# Which US administrative territory was the place of residence of Dakota Fanning ?
# Georgia
# And which administrative territory?
# Los Angeles
# How many cities and political territories are twin cities of that administrative territory ?
#
# How many cities and political territories are twin cities of Los Angeles?
#
# --------------------
#
# Which administrative territory is the birthplace of Diego Terrazas ?
#
# Which administrative territory is the birthplace of Diego Terrazas?
#
# --------------------
#
# Which administrative territory is the birthplace of Diego Terrazas ?
# Santa Cruz
# Which administrative territories are the sister cities of that one ?
#
# Which administrative territories are the sister cities of Santa Cruz?
#
# --------------------
#
# Which people were born at Santa Cruz and have the gender as male ?
#
# Which people were born at Santa Cruz and have the gender as male?
#
# --------------------
#
# Which musical instruments do more number of people know to play than tonbak ?
#
# Which musical instruments do more number of people know to play than tonbak?
#
# --------------------
#
# Which musical instruments do more number of people know to play than tonbak ?
# piano, harpsichord, viola
# And what about celesta?
#
# Which musical instruments do more number of people know to play than celesta?
#
# --------------------
#
# Which people were the first persons to come up with ondes Martenot or 912 Maritima ?
#
# Which people were the first persons to come up with ondes Martenot or 912 Maritima?
#
# --------------------
#
# Which people were the first persons to come up with ondes Martenot or 912 Maritima ?
# Friedrich Karl Arnold Schwassmann, Maurice Martenot
# Which people had that one as brother ?
# Did you mean Maurice Martenot ?
# Yes
#
# Which people had Maurice Martenot as brother?
#
# --------------------
#
# How many administrative territories do Guillaume belong to ?
#
# How many administrative territories do Guillaume belong to?
#
# --------------------
#
# How many administrative territories do Guillaume belong to ?
# 1
# And also tell me about Conor Finn?
#
# How many administrative territories does Conor Finn belong to?
#
# --------------------
#
# How many administrative territories do Guillaume belong to ?
# 1
# And also tell me about Conor Finn?
# 1
# And also tell me about Flérida de Nolasco?
#
# How many administrative territories does Flérida de Nolasco belong to?
#
# --------------------
#
# How many television programs did approximately 11 people do the dubbing for ?
#
# How many television programs did approximately 11 people do the dubbing for?
#
# --------------------
#
# Which recurring event did Ilian Iliev participate in ?
#
# Which recurring event did Ilian Iliev participate in?
#
# --------------------
#
# What do Ilian Iliev do for a living ?
#
# What do Ilian Iliev do for a living?
#
# --------------------
#
# Who are associated with the field of occupation association football manager and association football player ?
#
# Who are associated with the field of occupation association football manager and association football player?
#
# --------------------
#
# What is the origin of association football ?
#
# What is the origin of association football?
#
# --------------------
#
# Which person has specialisation in association football player ?
#
# Which person has specialisation in association football player?
#
# --------------------
#
# Which sports club is association football player a part of ?
#
# Which sports club is association football player a part of?
#
# --------------------
#
# What can be considered as category for Love Italian Style ?
#
# What can be considered as category for Love Italian Style?
#
# --------------------
#
# Which people wrote the script for Love Italian Style ?
#
# Which people wrote the script for Love Italian Style?
#
# --------------------
#
# Where did the expiration of Stefano Vanzina occur ?
#
# Where did the expiration of Stefano Vanzina occur?
#
# --------------------
#
# Where did the expiration of Stefano Vanzina occur ?
# Rome
# And what about Rufus S. Frost?
#
# Where did the expiration of Rufus S. Frost occur?
#
# --------------------
#
# What was the position for which Rufus S. Frost was appointed ?
#
# What was the position for which Rufus S. Frost was appointed?
#
# --------------------
#
# How many people are the patron saint of atleast 2 occupations ?
#
# How many people are the patron saint of at least 2 occupations?
#
# --------------------
#
# How many occupations are appointed by lesser number of authority organs or legislatures than United States Secretary of the Interior ?
#
# How many occupations are appointed by lesser number of authority organs or legislatures than United States Secretary of the Interior?
#
# --------------------
#
# How many occupations are appointed by lesser number of authority organs or legislatures than United States Secretary of the Interior ?
# 280
# And what about Lord Mayor of Dublin?
#
# How many occupations are appointed by lesser number of authority organs or legislatures than Lord Mayor of Dublin?
#
# --------------------
#
# Which people are the names of person who are the patron saints of more number of occupations than Saint Roch ?
#
# Which people are the names of person who are the patron saints of more number of occupations than Saint Roch?
#
# --------------------
#
# How many people were crew members of around 3 events and sports teams ?
#
# How many people were crew members of around 3 events and sports teams?
#
# --------------------
#
# Which works of art have comedy and drama film as genre ?
#
# Which works of art have comedy and drama film as genre?
#
# --------------------
#
# Which languages were used originally for the creation of San Papye or Minotaur ?
#
# Which languages were used originally for the creation of San Papye or Minotaur?
#
# --------------------
#
# Which administrative territory is the birthplace of George Ker ?
#
# Which administrative territory is the birthplace of George Ker?
#
# --------------------
#
# Which administrative territory is the work location of Antoni Rosal i Sala ?
#
# Which administrative territory is the work location of Antoni Rosal i Sala?
#
# --------------------
#
# Which administrative territory is the work location of Antoni Rosal i Sala ?
# Madrid
# Which sex does that person have ?
#
# Which sex does Antoni Rosal i Sala have?
#
# --------------------
#
# Which administrative territory is the work location of Antoni Rosal i Sala ?
# Madrid
# Which sex does that person have ?
# male
# Which language is that person capable of writing ?
#
# Which language is Antoni Rosal i Sala capable of writing?
#
# --------------------
#
# How many administrative territories are twin town of Madrid and Emirate of Dubai ?
#
# How many administrative territories are twin town of Madrid and Emirate of Dubai?
#
# --------------------
#
# Which occupations were a position held by Antoni Rosal i Sala or are the job of Dušan Srezojević ?
#
# Which occupations were a position held by Antoni Rosal i Sala or are the job of Dušan Srezojević?
#
# --------------------
#
# What is the ethnicity of Dušan Srezojević ?
#
# What is the ethnicity of Dušan Srezojević?
#
# --------------------
#
# Which language does Kathleen Blanco speak in ?
#
# Which language does Kathleen Blanco speak in?
#
# --------------------
#
# Which language does Kathleen Blanco speak in ?
# English
# Which classification schemes are that language a part of ?
#
# Which classification schemes is English a part of?
#
# --------------------
#
# Which classification schemes are Anglic languages and Anglo-Frisian languages a part of ?
#
# Which classification schemes are Anglic languages and Anglo-Frisian languages a part of?
#
# --------------------
#
# Which magazine genre was primarily based on English ?
#
# Which magazine genre was primarily based on English?
#
# --------------------
#
# Which magazine genre was primarily based on English ?
# Nordic Journal of English Studies
# Who was the compiler of that magazine genre ?
#
# Who was the compiler of Nordic Journal of English Studies?
#
# --------------------
#
# Which musical instruments are played by max number of people ?
#
# Which musical instruments are played by max number of people?
#
# --------------------
#
# Which musical instruments are played by max number of people ?
# piano
# Was that musical instrument invented or discovered by Thomas Hammond and Bartolomeo Cristofori ?
#
# Was the piano invented or discovered by Thomas Hammond and Bartolomeo Cristofori?
#
# --------------------
#
# How many classification schemes can be considered as genre of approximately the same number of works of art and applications as horror television series ?
#
# How many classification schemes can be considered as genre of approximately the same number of works of art and applications as horror television series?
#
# --------------------
#
# How many classification schemes can be considered as genre of approximately the same number of works of art and applications as horror television series ?
# 63
# And what about bottle episode?
#
# How many classification schemes can be considered as genre of approximately the same number of works of art and applications as bottle episode?
#
# --------------------
#
# Which is an edition or translation of English ?
#
# Which is an edition or translation of English?
#
# --------------------
#
# What is the religion associated with Adolf Fritzen ?
#
# What is the religion associated with Adolf Fritzen?
#
# --------------------
#
# Which political territory is the native country of Adolf Fritzen ?
#
# Which political territory is the native country of Adolf Fritzen?
#
# --------------------
#
# Which political territory is the native country of Adolf Fritzen ?
# Germany
# And how about Peter Götz von Olenhusen?
#
# Which political territory is the native country of Peter Götz von Olenhusen?
#
# --------------------
#
# Is Maurice Léna and Richard McLaren the head of state of Germany ?
#
# Is Maurice Léna and Richard McLaren the head of state of Germany?
#
# --------------------
#
# Which political territories have diplomatic associations with max number of political territories ?
#
# Which political territories have diplomatic associations with max number of political territories?
#
# --------------------
#
# Which political territories are known to have diplomatic connections with min number of political territories ?
#
# Which political territories are known to have diplomatic connections with min number of political territories?
#
# --------------------
#
# Which administrative territories have diplomatic relations with Germany and are Amuri a part of ?
#
# Which administrative territories have diplomatic relations with Germany and are Amuri a part of?
#
# --------------------
#
# Which administrative territories have diplomatic relations with Germany and are Amuri a part of ?
# Indonesia
# And also tell me about Halsa Church?
#
# Which administrative territories have diplomatic relations with Germany and is Halsa Church a part of?
#
# --------------------
#
# Which political territories have max number of french administrative divisions or administrative territories as their capital ?
#
# Which political territories have max number of french administrative divisions or administrative territories as their capital?
#
# --------------------
#
# Which party does Ray Franz belong to ?
#
# Which party does Ray Franz belong to?
#
# --------------------
#
# Which party does Ray Franz belong to ?
# Michigan Republican Party
# Which language does that person speak in ?
#
# Which language does Ray Franz speak in?
#
# --------------------
#
# Which party does Ray Franz belong to ?
# Michigan Republican Party
# Which language does that person speak in ?
# English
# Which classification schemes are that language a part of ?
#
# Which classification schemes is English a part of?
#
# --------------------
#
# Which party does Ray Franz belong to ?
# Michigan Republican Party
# Which language does that person speak in ?
# English
# Which classification schemes are that language a part of ?
# Anglic languages, Anglo-Frisian languages
# Are Sateliti a component of those classification schemes ?
#
# Are Sateliti a component of Anglic languages, Anglo-Frisian languages?
#
# --------------------
#
# Is Anglic languages a portion of Oruç Reis-class submarine and West Germanic languages ?
#
# Is Anglic languages a portion of Oruç Reis-class submarine and West Germanic languages?
#
# --------------------
#
# Which film has been dubbed by English ?
#
# Which film has been dubbed by English?
#
# --------------------
#
# Which classification schemes are Anglo-Frisian languages a component of or are the vessel classes of German submarine U-251 ?
#
# Which classification schemes are Anglo-Frisian languages a component of or are the vessel classes of German submarine U-251?
#
# --------------------
#
# How many classification schemes are parts of approximately the same number of behaviors and activities as Media psychology ?
#
# How many classification schemes are parts of approximately the same number of behaviors and activities as Media psychology?
#
# --------------------
#
# Which ship class has German Type VIIC submarine as its namesake ?
#
# Which ship class has German Type VIIC submarine as its namesake?
#
# --------------------
#
# Who wrote the music for A Friend Will Come Tonight ?
#
# Who wrote the music for A Friend Will Come Tonight?
#
# --------------------
#
# Who wrote the music for A Friend Will Come Tonight ?
# Arthur Honegger
# Where did that work of art originate ?
#
# Where did A Friend Will Come Tonight originate?
#
# --------------------
#
# How many administrative territories are known to have diplomatic connections with atleast 12 administrative territories ?
#
# How many administrative territories are known to have diplomatic connections with atleast 12 administrative territories?
#
# --------------------
#
# How many administrative territories are greater number of educational institutions or ship types a part of than Togo ?
#
# How many administrative territories are greater number of educational institutions or ship types a part of than Togo?
#
# --------------------
#
# How many political territories have diplomatic relations with atmost 107 administrative territories ?
#
# How many political territories have diplomatic relations with atmost 107 administrative territories?
#
# --------------------
#
# Which people wrote the script for A Friend Will Come Tonight or were performed by Fernande ?
#
# Which people wrote the script for A Friend Will Come Tonight or were performed by Fernande?
#
# --------------------
#
# Which works of art are demonstrated in greater number of artwork series and works of art than The Great Sphinx ?
#
# Which works of art are demonstrated in greater number of artwork series and works of art than The Great Sphinx?
#
# --------------------
#
# Which works of art are demonstrated in greater number of artwork series and works of art than The Great Sphinx ?
# Laocoön and His Sons, Dying Gaul, Borghese Gladiator
# And how about Torso in Metal from Rock Drill?
#
# Which works of art are demonstrated in greater number of artwork series and works of art than Torso in Metal from Rock Drill?
#
# --------------------
#
# Which works of art are demonstrated in greater number of artwork series and works of art than The Great Sphinx ?
# Laocoön and His Sons, Dying Gaul, Borghese Gladiator
# And how about Torso in Metal from Rock Drill?
# Laocoön and His Sons, Dying Gaul, Borghese Gladiator
# Does Ed io anche sono architetto demonstrate those works of art ?
#
# Does Ed io anche sono architetto demonstrate Torso in Metal from Rock Drill?
#
# --------------------
#
# Is Jacques Companéez a civilian of Tawern and France ?
#
# Is Jacques Companéez a civilian of Tawern and France?
#
# --------------------
#
# Is Laocoön and His Sons situated in Kindsbach ?
#
# Is Laocoön and His Sons situated in Kindsbach?
#
# --------------------
#
# Which sex does Jerry Jones have ?
#
# Which sex does Jerry Jones have?
#
# --------------------
#
# Which administrative territory is the country of citizenship of Jerry Jones ?
#
# Which administrative territory is the country of citizenship of Jerry Jones?
#
# --------------------
#
# Which administrative territory is the country of citizenship of Jerry Jones ?
# United States of America
# And what about Matti Remes?
#
# Which administrative territory is the country of citizenship of Matti Remes?
#
# --------------------
#
# Does Finland have tactful political relations with Boa Nova and Canada ?
#
# Does Finland have tactful political relations with Boa Nova and Canada?
#
# --------------------
#
# Which construction has its designs created by Finland ?
#
# Which construction has its designs created by Finland?
#
# --------------------
#
# Which construction has its designs created by Finland ?
# Kilden Performing Arts Centre
# Which person has the highest formal authority in that administrative territory ?
#
# Which person has the highest formal authority in Finland?
#
# --------------------
#
# Which construction has its designs created by Finland ?
# Kilden Performing Arts Centre
# Which person has the highest formal authority in that administrative territory ?
# Sauli Niinistö
# Does Pradist Democratic Movement have that person as its chairperson ?
#
# Does Pradist Democratic Movement have Sauli Niinistö as its chairperson?
#
# --------------------
#
# Which language can Roger Handasyd read ?
#
# Which language can Roger Handasyd read?
#
# --------------------
#
# Which occupation was a position occupied by Roger Handasyd ?
#
# Which occupation was a position occupied by Roger Handasyd?
#
# --------------------
#
# What are English a country of origin of ?
#
# What are English a country of origin of?
#
# --------------------
#
# Which state applies to jurisdiction of Member of Parliament in the Parliament of Great Britain ?
#
# Which state applies to jurisdiction of Member of Parliament in the Parliament of Great Britain?
#
# --------------------
#
# Which person has the profession as Member of Parliament in the Parliament of Great Britain ?
#
# Which person has the profession as Member of Parliament in the Parliament of Great Britain?
#
# --------------------
#
# Which person has the profession as Member of Parliament in the Parliament of Great Britain ?
# Francis Gregg
# Which sex does that person possess ?
#
# Which sex does Francis Gregg possess?
#
# --------------------
#
# Which person has the profession as Member of Parliament in the Parliament of Great Britain ?
# Francis Gregg
# Which sex does that person possess ?
# male
# Who has that one as a father ?
#
# Who has Francis Gregg as a father?
#
# --------------------
#
# Which musical instruments can min number of people perform with ?
#
# Which musical instruments can min number of people perform with?
#
# --------------------
#
# Which occupations are demonstrated in around the same number of medias and heraldic symbols as washerwoman ?
#
# Which occupations are demonstrated in around the same number of medias and heraldic symbols as washerwoman?
#
# --------------------
#
# Which occupations are demonstrated in around the same number of medias and heraldic symbols as washerwoman ?
# farmer, tailor, librarian
# And how about house painter?
#
# Which occupations are demonstrated in around the same number of medias and heraldic symbols as house painter?
#
# --------------------
#
# Where was Blas Irala born ?
#
# Where was Blas Irala born?
#
# --------------------
#
# Where was Blas Irala born ?
# Piribebuy
# What is situated at that administrative country subdivision ?
#
# What is situated at Piribebuy?
#
# --------------------
#
# How many people have place of birth as Piribebuy ?
#
# How many people have place of birth as Piribebuy?
#
# --------------------
#
# How many people have place of birth as Piribebuy ?
# 5
# And what about Lubbock?
#
# How many people have place of birth as Lubbock?
#
# --------------------
#
# How many people have place of birth as Piribebuy ?
# 5
# And what about Lubbock?
# 99
# Which business enterprises have procured license for broadcasting to that administrative territory ?
#
# Which business enterprises have procured license for broadcasting to Lubbock?
#
# --------------------
#
# How many people have place of birth as Piribebuy ?
# 5
# And what about Lubbock?
# 99
# Which business enterprises have procured license for broadcasting to that administrative territory ?
# KTXT-FM, KDAV, KJDL
# Which administrative territory is that business enterprise present in ?
# Did you mean KJDL ?
# Yes
#
# Which administrative territory is KJDL present in?
#
# --------------------
#
# How many people have place of birth as Piribebuy ?
# 5
# And what about Lubbock?
# 99
# Which business enterprises have procured license for broadcasting to that administrative territory ?
# KTXT-FM, KDAV, KJDL
# Which administrative territory is that business enterprise present in ?
# Did you mean KJDL ?
# Yes
# United States of America
# Does Federated States of Micronesia share the border with that one ?
#
# Does Federated States of Micronesia share the border with United States of America?
#
# --------------------
#
# Which sport was Vyacheslav Lyskin a part of ?
#
# Which sport was Vyacheslav Lyskin a part of?
#
# --------------------
#
# Which sport was Vyacheslav Lyskin a part of ?
# association football
# Which territory is the country of origin of that sport ?
#
# Which territory is the country of origin of association football?
#
# --------------------
#
# Which sports are considered to be the main utilization of atleast 1 structures or ship types ?
#
# Which sports are considered to be the main utilization of atleast 1 structures or ship types?
#
# --------------------
#
# What is the profession of Vyacheslav Lyskin ?
#
# What is the profession of Vyacheslav Lyskin?
#
# --------------------
#
# What is the profession of Vyacheslav Lyskin ?
# association football player
# What is that occupation a part of ?
#
# What is the occupation of association football player a part of?
#
# --------------------
#
# Which the chemical bond that represents the molecular function of DNA ligase (NAD+)    FP1847 ?
#
# Which the chemical bond that represents the molecular function of DNA ligase (NAD+) FP1847?
#
# --------------------
#
# Which the chemical bond that represents the molecular function of DNA ligase (NAD+)    FP1847 ?
# metal ion binding
# Where is that nutrient found ?
#
# Where is metal ion binding found?
#
# --------------------
#
# How many nutrients do less number of drugs or nutrients communicate with than ALK tyrosine kinase receptor ?
#
# How many nutrients do less number of drugs or nutrients communicate with than ALK tyrosine kinase receptor?
#
# --------------------
#
# How many nutrients do less number of drugs or nutrients communicate with than ALK tyrosine kinase receptor ?
# 539
# And what about Gamma-aminobutyric acid receptor subunit alpha-5?
#
# What about Gamma-aminobutyric acid receptor subunit alpha-5? How many nutrients do less number of drugs or nutrients communicate with than Gamma-aminobutyric acid receptor subunit alpha-5?
#
# --------------------
#
# How many nutrients do approximately the same number of nutrients or drugs collaborate with as Neuropeptide S receptor ?
#
# How many nutrients do approximately the same number of nutrients or drugs collaborate with as Neuropeptide S receptor?
#
# --------------------
#
# What dynasty does Ernest, Duke of Opava belong to ?
#
# What dynasty does Ernest, Duke of Opava belong to?
#
# --------------------
#
# Which people have Ernest, Duke of Opava as their brother ?
#
# Which people have Ernest, Duke of Opava as their brother?
#
# --------------------
#
# Which male person was the parent of Ernest, Duke of Opava ?
#
# Which male person was the parent of Ernest, Duke of Opava?
#
# --------------------
#
# Which male person was the parent of Ernest, Duke of Opava ?
# Přemek I, Duke of Opava
# And what about Charlotte Wray?
#
# What about Charlotte Wray?
#
# --------------------
#
# Which noble families have around 1 monarchic systems or administrative territories as the type of government ?
#
# Which noble families have around 1 monarchic systems or administrative territories as the type of government?
#
# --------------------
#
# ...
#
# Which national sports teams were participants in 1966 FIFA World Cup but not 1978 FIFA World Cup?
#
# --------------------
#
# Which sex does Tim Simpson have ?
#
# Which sex does Tim Simpson have?
#
# --------------------
#
# Which sex does Tim Simpson have ?
# male
# And also Justin Hunter
#
# Which sex does Justin Hunter have?
#
# --------------------
#
# Which sex does Tim Simpson have ?
# male
# And also Justin Hunter
# male
# Is Jacob van der Sleyden a that sex ?
#
# Is Jacob van der Sleyden a male?
#
# --------------------
#
# Which occupation has Jules Vannérus as his/her 's career ?
#
# Which occupation has Jules Vannérus as his/her's career?
#
# --------------------
#
# Which occupation has Jules Vannérus as his/her 's career ?
# archivist
# Which sex does that person possess ?
#
# Which sex does Jules Vannérus possess?
#
# --------------------
#
# Which occupation has Jules Vannérus as his/her 's career ?
# archivist
# Which sex does that person possess ?
# male
# And also Joseph Barnby
#
# Which sex does Joseph Barnby possess?
#
# --------------------
#
# What is the military school where Fénelon François Germain Passaga was educated ?
#
# What is the military school where Fénelon François Germain Passaga was educated?
#
# --------------------
#
# What is the military school where Fénelon François Germain Passaga was educated ?
# Ecole Spéciale Militaire de Saint-Cyr
# And also Symphorien Boittelle
#
# What is the military school where Symphorien Boittelle was educated?
#
# --------------------
#
# What is the military school where Fénelon François Germain Passaga was educated ?
# Ecole Spéciale Militaire de Saint-Cyr
# And also Symphorien Boittelle
# Ecole Spéciale Militaire de Saint-Cyr
# Which french administrative division is the headquarter location of that military school ?
#
# Which french administrative division is the headquarter location of Ecole Spéciale Militaire de Saint-Cyr?
#
# --------------------
#
# Which works of art have Edmund Lowe in their star cast and do n't have United Kingdom as their origination points ?
#
# Which works of art have Edmund Lowe in their star cast and don't have United Kingdom as their origination points?
#
# --------------------
#
# Which metabolic processes are 6-phospho-beta-glucosidase    AMED_1157 but not Dimethylaniline monooxygenase [N-oxide-forming] 3 involved in ?
#
# Which metabolic processes are 6-phospho-beta-glucosidase AMED_1157 but not Dimethylaniline monooxygenase [N-oxide-forming] 3 involved in?
#
# --------------------
#
# Which administrative territories have ambassadorial relations with Australia but not Canada ?
#
# Which administrative territories have ambassadorial relations with Australia but not Canada?
#
# --------------------
#
# Which works of art express David but not man ?
#
# Which works of art express David but not man?
#
# --------------------
#
# Which administrative territories holds diplomatic relationship with Germany and are not Mersin Tennis Complex present in ?
#
# Which administrative territories hold diplomatic relationships with Germany and are not Mersin Tennis Complex present in?
#
# --------------------
#
# Which political territories have diplomatic relations with Thailand and are not Clarkes Hill present in ?
#
# Which political territories have diplomatic relations with Thailand and are not Clarkes Hill present in?
#
# --------------------
#
# Which administrative territories have diplomatic relationships with Argentina and are not Klyuchyovka River present in ?
#
# Which administrative territories have diplomatic relationships with Argentina and are not Klyuchyovka River present in?
#
# --------------------
#
# Which administrative territories have diplomatic relationships with Argentina and are not Klyuchyovka River present in ?
# Brazil, United States of America, Italy
# Who did that administrative territory sponsor ?
# Did you mean Brazil ?
# No, I meant United States of America. Could you tell me the answer for that?
#
# Who did United States of America sponsor?
#
# --------------------
#
# Which administrative territories have diplomatic relationships with Germany and are not square des Grès present in ?
#
# Which administrative territories have diplomatic relationships with Germany and are not square des Grès present in?
#
# --------------------
#
# Which people participated in 1964 Winter Olympics and do not have language named French ?
#
# Which people participated in 1964 Winter Olympics and do not have language named French?
#
# --------------------
#
# Which political territories have diplomatic relations with Australia and are not the countries of citizenship of Heinrich Anselm Promnitz ?
#
# Which political territories have diplomatic relations with Australia and are not the countries of citizenship of Heinrich Anselm Promnitz?
#
# --------------------
#
# Which political territories have diplomatic relations with Australia and are not the countries of citizenship of Heinrich Anselm Promnitz ?
# Austria, Antigua and Barbuda, The Bahamas, Grenada, Solomon Islands, Denmark, Papua New Guinea, Canada, New Zealand, Jamaica
# Are Australia known to have diplomatic connections with those ones ?
#
# Are Australia known to have diplomatic connections with Austria, Antigua and Barbuda, The Bahamas, Grenada, Solomon Islands, Denmark, Papua New Guinea, Canada, New Zealand, Jamaica?
#
# --------------------
#
# Which international organizations were Singapore but not Czech Republic a member of ?
#
# Which international organizations were Singapore but not Czech Republic a member of?
#
# --------------------
#
# Which international organizations were Singapore but not Czech Republic a member of ?
# ASEAN, Alliance of Small Island States, Commonwealth of Nations, Asian Development Bank
# Are Singapore a part of those international organizations ?
#
# Are Singapore a part of ASEAN, Alliance of Small Island States, Commonwealth of Nations, and Asian Development Bank?
#
# --------------------
#
# Which administrative territories have a diplomatic relationship with Germany and are not the countries of citizenship of Gazanfer Aydın ?
#
# Which administrative territories have a diplomatic relationship with Germany and are not the countries of citizenship of Gazanfer Aydın?
#
# --------------------
#
# Which people are a native of British Empire but not United States of America ?
#
# Which people are a native of British Empire but not United States of America?
#
# --------------------
#
# Which people have a job as ophthalmologist but not association football player ?
#
# Which people have a job as ophthalmologist but not association football player?
#
# --------------------
#
# Which occupations have David Walker as his/her 's career ?
#
# Which occupations have David Walker as his/her 's career ?
#
# --------------------
#
# Which occupations have David Walker as his/her 's career ?
# banker, entrepreneur
# But not Najm Sheikh
#
# Which occupations have David Walker as his career?
#
# --------------------
#
# Which political territories are the origins of SheZow but not Maximum Choppage ?
#
# Which political territories are the origins of SheZow but not Maximum Choppage?
#
# --------------------
#
# Which collectables have Old Norse language but not English as their original language of creation ?
#
# Which collectables have Old Norse language but not English as their original language of creation?
#
# --------------------
#
# Which collectables have Old Norse language but not English as their original language of creation ?
# Eyrbyggja saga
# Is Old Norse language considered to be the original language of creation of that collectable ?
#
# Is Old Norse language considered to be the original language of creation of Eyrbyggja saga?
#
# --------------------
#
# Which drugs show a significant interaction with Clarithromycin but not lovastatin ?
#
# Which drugs show a significant interaction with Clarithromycin but not lovastatin?
#
# --------------------
#
# Which occupations have Wilhelm Storck but not Artúr Elek as his/her as a career ?
#
# Which occupations have Wilhelm Storck but not Artúr Elek as his/her as a career?
#
# --------------------
#
# Which occupations have Wilhelm Storck but not Artúr Elek as his/her as a career ?
# germanist, romanist, university teacher
# Do Wilhelm Ludwig Holland have the profession of those occupations ?
#
# Do Wilhelm Ludwig Holland have the profession of germanist, romanist, university teacher?
#
# --------------------
#
# Which works of art originate at Czech Republic but not Hungary ?
#
# Which works of art originate at Czech Republic but not Hungary?
#
# --------------------
#
# Which drugs interacts with D(2) dopamine receptor but not Muscarinic acetylcholine receptor M1 ?
#
# Which drugs interact with D(2) dopamine receptor but not Muscarinic acetylcholine receptor M1?
#
# --------------------
#
# Which drugs interacts with D(2) dopamine receptor but not Muscarinic acetylcholine receptor M1 ?
# Some of them are brexpiprazole, aripiprazole, chlorpromazine, mesoridazine, benzquinamide, sertindole, promazine, pramipexole, pimozide, ziprasidone
# Does D(2) dopamine receptor interact with those drugs ?
#
# Does D(2) dopamine receptor interact with brexpiprazole, aripiprazole, chlorpromazine, mesoridazine, benzquinamide, sertindole, promazine, pramipexole, pimozide, ziprasidone?
#
# --------------------
#
# Which occupations do Jean-François Michel but not Josep Fàbrega do for a living ?
#
# Which occupations do Jean-François Michel but not Josep Fàbrega do for a living?
#
# --------------------
#
# Which occupations do Jean-François Michel but not Josep Fàbrega do for a living ?
# conductor, trumpeter, musicologist
# Do Gary Langford have the profession of those occupations ?
#
# Which occupations does Gary Langford have the profession of?
#
# --------------------
#
# Which recurring events did Argentina national football team but not Alan Hansen participate in ?
#
# Which recurring events did Argentina national football team but not Alan Hansen participate in?
#
# --------------------
#
# Which chemical bonds represents the molecular function of Zinc finger protein 40 but not Putative pleckstrin homology domain-containing family M member 1P ?
#
# Which chemical bonds represents the molecular function of Zinc finger protein 40 but not Putative pleckstrin homology domain-containing family M member 1P?
#
# --------------------
#
# Which chemical bonds represents the molecular function of Zinc finger protein 40 but not Putative pleckstrin homology domain-containing family M member 1P ?
# zinc ion binding
# Does hypothetical protein    lpg2920 have that chemical bond as its molecular function ?
#
# Does hypothetical protein lpg2920 have zinc ion binding as its molecular function?
#
# --------------------
#
# Which drugs do 5-hydroxytryptamine receptor 2B but not 5-hydroxytryptamine receptor 2C contact with ?
#
# Which drugs do 5-hydroxytryptamine receptor 2B but not 5-hydroxytryptamine receptor 2C contact with?
#
# --------------------
#
# Which drugs do 5-hydroxytryptamine receptor 2B but not 5-hydroxytryptamine receptor 2C contact with ?
# fluoxetine, melatonin, pindolol, haloperidol, yohimbine
# Does glycerol metabolism activator    PA1978 interact with those drugs ?
#
# Does glycerol metabolism activator PA1978 interact with fluoxetine, melatonin, pindolol, haloperidol, or yohimbine?
#
# --------------------
#
# Which political organizations promote conservatism but not Christian democracy ?
#
# Which political organizations promote conservatism but not Christian democracy?
#
# --------------------
#
# Which system software are the platforms for which Savage: The Battle for Newerth but not Tomb Raider: Underworld were developed ?
#
# Which system software are the platforms for which Savage: The Battle for Newerth but not Tomb Raider: Underworld were developed?
#
# --------------------
#
# Which system software are the platforms for which Savage: The Battle for Newerth but not Tomb Raider: Underworld were developed ?
# Linux
# Was that system software manufactured by GNU and Request Tracker ?
#
# Was Linux manufactured by GNU and Request Tracker?
#
# --------------------
#
# Which administrative territories have a diplomatic relationship with Israel but not Germany ?
#
# Which administrative territories have a diplomatic relationship with Israel but not Germany?
#
# --------------------
#
# Which national sports teams took part in 1974 FIFA World Cup but not UEFA Euro 1984 ?
#
# Which national sports teams took part in 1974 FIFA World Cup but not UEFA Euro 1984?
#
# --------------------
#
# Which thoroughfares are situated in Hungary but not Czech Republic ?
#
# Which thoroughfares are situated in Hungary but not Czech Republic?
#
# --------------------
#
# Which occupations do George Lamsa but not Antonio Prete do for a living ?
#
# Which occupations do George Lamsa but not Antonio Prete do for a living?
#
# --------------------
#
# Which occupations do George Lamsa but not Antonio Prete do for a living ?
# translator, theologian
# Do Hermann Hakel have a job as those occupations ?
#
# Which occupations does Hermann Hakel have a job as those occupations?
#
# --------------------
#
# Which recurring events did Sweden national football team but not Mexico national football team participate in ?
#
# Which recurring events did Sweden national football team but not Mexico national football team participate in?
#
# --------------------
#
# Which administrative territories are Netherlands but not Meelbesstraat located in ?
#
# Which administrative territories are Netherlands but not Meelbesstraat located in?
#
# --------------------
#
# Which chemical bonds represent molecular function of phenylalanyl-tRNA synthetase subunit beta    aq_1730 but not chaperone protein DnaJ    CT_341 ?
#
# Which chemical bonds represent molecular function of phenylalanyl-tRNA synthetase subunit beta aq_1730 but not chaperone protein DnaJ CT_341?
#
# --------------------
#
# Which chemical bonds represent molecular function of phenylalanyl-tRNA synthetase subunit beta    aq_1730 but not chaperone protein DnaJ    CT_341 ?
# magnesium ion binding
# And how about Liberté, j'écris ton nom?
#
# Which chemical bonds represent molecular function of Liberté, j'écris ton nom but not chaperone protein DnaJ CT_341?
#
# --------------------
#
# Which administrative territories are sister towns of Chicago but not Helsinki ?
#
# Which administrative territories are sister towns of Chicago but not Helsinki?
#
# --------------------
#
# Which administrative territories are sister towns of Chicago but not Helsinki ?
# Some of them are Warsaw, Toronto, Kiryat Gat, Amman, Galway, Athens, Accra, Düsseldorf, Mexico City, Durban
# Are Eda-Kita twin town of those ones ?
#
# Are Eda-Kita twin town of Warsaw, Toronto, Kiryat Gat, Amman, Galway, Athens, Accra, Düsseldorf, Mexico City, Durban?
#
# --------------------
#
# What is the nucleic acid sequence that is encoded by exonuclease V subunit beta    O3K_05410 ?
#
# What is the nucleic acid sequence that is encoded by exonuclease V subunit beta O3K_05410?
#
# --------------------
#
# What is the nucleic acid sequence that is encoded by exonuclease V subunit beta    O3K_05410 ?
# exonuclease V subunit beta    O3K_05410
# Which chemical bonds represent molecular function of that nutrient ?
#
# Which chemical bonds represent molecular function of exonuclease V subunit beta?
#
# --------------------
#
# What is the nucleic acid sequence that is encoded by exonuclease V subunit beta    O3K_05410 ?
# exonuclease V subunit beta    O3K_05410
# Which chemical bonds represent molecular function of that nutrient ?
# magnesium ion binding, metal ion binding
# But not hypothetical protein    FTT_0554
#
# Which chemical bonds represent molecular function of exonuclease V subunit beta?
#
# --------------------
#
# Which city was Pierre Laffont born in ?
#
# Which city was Pierre Laffont born in?
#
# --------------------
#
# Which city was Pierre Laffont born in ?
# Marseille
# Which administrative territories are the sister cities of that city ?
#
# Which administrative territories are the sister cities of Marseille?
#
# --------------------
#
# Which city was Pierre Laffont born in ?
# Marseille
# Which administrative territories are the sister cities of that city ?
# Shanghai, Odessa, Naples
# But not Bologna
#
# Which administrative territories are the sister cities of Marseille?
#
# --------------------

# %%
json.dump(data, open('data/processed_spice_data/dev_each_type_50.json', 'w'), indent=2)

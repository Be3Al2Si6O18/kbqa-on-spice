# %%
import json
import os
import re
import numpy as np
import itertools
from utils.execute_query import execute_query
from utils.parse_expr import expression_to_sparql, ParseError

os.environ['CUDA_VISIBLE_DEVICES'] = '3'
from retriever.semantic_retriever import SemanticRetriever

exp_name = 'my_top1'
test_data = json.load(open(f'output/{exp_name}/cores.json', 'r'))

entity_retriever = SemanticRetriever('entity')
relation_retriever = SemanticRetriever('relation')
type_retriever = SemanticRetriever('type')
rela_mid_to_faiss_index = {mid: i for i, mid in enumerate(relation_retriever.mid_list)}
rela_fn_to_faiss_index = {fn: i for i, fn in enumerate(relation_retriever.fn_list)}
type_mid_to_faiss_index = {mid: i for i, mid in enumerate(type_retriever.mid_list)}
type_fn_to_faiss_index = {mid: i for i, mid in enumerate(type_retriever.fn_list)}
wikidata_mid_to_fn = json.load(open('data/wikidata_mid_to_fn.json', 'r'))

# %%
# top_1 linking
def sub_fn_to_mid(expression):
    func_list = ['R', 'JOIN', 'AND', 'OR', 'DIFF', 'VALUES', 'DISTINCT', 'COUNT', 'GROUP_COUNT', 'GROUP_SUM', 'LT', 'LE', 'EQ', 'GE', 'GT', 'ARGMIN', 'ARGMAX', 'ALL', 'IS_TRUE']
    seg_list = expression.split()
    last_token, second_last_token = '', ''
    for i in range(len(seg_list)):
        token = seg_list[i].strip(')(')
        if token not in func_list and not token.isdigit():
            if last_token in ['R', 'JOIN'] or second_last_token == 'IS_TRUE':
                retriever = relation_retriever
            elif last_token == 'instance_of':
                retriever = type_retriever
            else:
                retriever = entity_retriever
            mid = retriever.semantic_search(token)[0][1]
            seg_list[i] = seg_list[i].replace(token, mid)
        second_last_token = last_token
        last_token = token
    new_expression = ' '.join(seg_list)
    return new_expression

def sub_mid_to_fn(expression):
    seg_list = expression.split()
    for i in range(len(seg_list)):
        token = seg_list[i].strip(')(')
        if token.startswith('P') or token.startswith('Q'):
            fn = wikidata_mid_to_fn.get(token, "unknown_entity")
            seg_list[i] = seg_list[i].replace(token, fn)
    new_expression = ' '.join(seg_list)
    return new_expression

# %%
# top_k linking

num_variants = 1

def is_close(expr):
    stack = 0
    for char in expr:
        if char == '(':
            stack += 1
        elif char == ')':
            if stack == 0:
                return False
            stack -= 1
    return stack == 0

def fix_core(core):
    tokens = [token.replace('(', '').replace(')', '') for token in core.split()]
    index = 0
    def parse_core():
        nonlocal index
        func_list = ['JOIN', 'R', 'AND', 'VALUES', 'IS_TRUE']
        token = tokens[index]
        if token in func_list:
            index += 1
            args = []
            if token == 'IS_TRUE':
                for _ in range(3):
                    args.append(parse_core())
            elif token == 'JOIN':
                for _ in range(2):
                    args.append(parse_core())
            elif token == 'R':
                args.append(parse_core())
            elif token == 'AND':
                while index < len(tokens):
                    args.append(parse_core())
            else:
                while index < len(tokens) and tokens[index] not in func_list:
                    args.append(parse_core())
            return f'({token} {' '.join(args)})'
        else:
            value = token
            index += 1
            return value
    try:
        fixed_core = parse_core()
    except:
        fixed_core = core
    return fixed_core

def get_1hop_relations(entity):
    query = "SELECT DISTINCT ?x0 WHERE { { ?x1 ?x0 wd:" + entity + " . } UNION { wd:" + entity + " ?x0 ?x1 . } }"
    return [rela for rela in execute_query(query) if rela[0] == 'P']

def calculate_rela_similarity(vec1, rela_mid):
    def get_vector_from_mid(rela_mid):
        if rela_mid not in relation_retriever.mid_list:
            rela_mid = relation_retriever.semantic_search(wikidata_mid_to_fn[rela_mid])[0][1]
        return relation_retriever.index.reconstruct(rela_mid_to_faiss_index[rela_mid])

    vec2 = get_vector_from_mid(rela_mid)
    return np.dot(vec1, vec2) / (np.linalg.norm(vec1) * np.linalg.norm(vec2))

def calculate_type_similarity(vec1, type_mid):
    def get_vector_from_mid(type_mid):
        if type_mid not in type_retriever.mid_list:
            type_mid = type_retriever.semantic_search(wikidata_mid_to_fn[type_mid])[0][1]
        return type_retriever.index.reconstruct(type_mid_to_faiss_index[type_mid])

    vec2 = get_vector_from_mid(type_mid)
    return np.dot(vec1, vec2) / (np.linalg.norm(vec1) * np.linalg.norm(vec2))

def add_reverse(org_exp):
    final_candi = [org_exp]
    total_join = 0
    list_seg = org_exp.split(" ")
    for seg in list_seg:
        if "JOIN" in seg:
            total_join += 1
    for i in range(total_join):
        final_candi = final_candi + add_reverse_index(final_candi, i + 1)
    return final_candi

def add_reverse_index(list_of_e, join_id):
    added_list = []
    list_of_e_copy = list_of_e.copy()
    for exp in list_of_e_copy:
        list_seg = exp.split(" ")
        count = 0
        for i, seg in enumerate(list_seg):
            if "JOIN" in seg and list_seg[i + 1] != "(R":
                count += 1
                if count != join_id:
                    continue
                if list_seg[i + 1] == 'P31':
                    break
                list_seg[i + 1] = "(R " + list_seg[i + 1] + ")"
                added_list.append(" ".join(list_seg))
                break
            if "JOIN" in seg and list_seg[i + 1] == "(R":
                count += 1
                if count != join_id:
                    continue
                list_seg[i + 1] = ""
                list_seg[i + 2] = list_seg[i + 2][:-1]
                added_list.append(" ".join(" ".join(list_seg).split()))
                break
    return added_list

def bound_to_existed(s_expression):
    results = []
    query_count = 0
    expression_segment = s_expression.split(" ")
    expression_segment_copy = expression_segment.copy()

    type_count = 0
    type_replace_dict = {}
    for i, seg in enumerate(expression_segment):
        processed_seg = seg.strip(')')
        if i > 0 and expression_segment[i - 1] == 'instance_of':
            type_count += 1
            expression_segment_copy[i - 1] = 'P31'
            type_replace_dict[i] = f'?t{type_count}'
            expression_segment_copy[i] = type_replace_dict[i] + ')' * (len(seg) - len(processed_seg))

    enti_replace_dict = {}
    for i, seg in enumerate(expression_segment):
        processed_seg = seg.strip(')')
        if processed_seg[0] != '(' and not processed_seg.isdigit() and not (i > 0 and expression_segment[i - 1] in ['(R', '(JOIN'] or i > 1 and expression_segment[i - 2] == '(IS_TRUE') and not expression_segment[i - 1] == 'instance_of':
            enti_replace_dict[i] = [mid for score, mid, fn in entity_retriever.semantic_search(processed_seg)]
    if len(enti_replace_dict) > 4:
        top_k = 1
    elif len(enti_replace_dict) > 2:
        top_k = 1
    else:
        top_k = 1

    for i in enti_replace_dict:
        enti_replace_dict[i] = enti_replace_dict[i][:top_k]
    
    # print({id: [wikidata_mid_to_fn[mid] for mid in mids] for id, mids in enti_replace_dict.items()})
    
    combinations = list(enti_replace_dict.values())
    all_iters = list(itertools.product(*combinations)) # 所有可能的实体替换方案
    enti_index = list(enti_replace_dict.keys()) # 待替换实体在expression_segment中的index
    for iters in all_iters:
        for i in range(len(iters)):
            cur_enti = expression_segment[enti_index[i]]
            suffix = ')' * (len(cur_enti) - len(cur_enti.strip(')')))
            expression_segment_copy[enti_index[i]] = iters[i] + suffix

        rela_replace_dict = {}
        for j, seg in enumerate(expression_segment):
            processed_seg = seg.strip(')')
            if processed_seg[0] != '(' and not processed_seg.isdigit() and (j > 0 and expression_segment[j - 1] in ['(R', '(JOIN'] or j > 1 and expression_segment[j - 2] == '(IS_TRUE') and not processed_seg == 'instance_of':
                if expression_segment[j + 1] in ['(JOIN', '(AND']:
                    rela_replace_dict[j] = [mid for score, mid, fn in relation_retriever.semantic_search(processed_seg)]
                else:
                    possible_rela = []
                    if expression_segment[j + 1] == '(VALUES':
                        index = j + 2
                        while index < len(expression_segment) and expression_segment[index][0] != '(':
                            possible_rela += get_1hop_relations(expression_segment_copy[index].strip(')'), )
                            query_count += 1
                            index += 1
                    else:
                        possible_rela += get_1hop_relations(expression_segment_copy[j + 1].strip(')'))
                        query_count += 1
                    possible_rela = set(possible_rela)
                    seg_fn = relation_retriever.semantic_search(processed_seg)[0][2] if processed_seg not in relation_retriever.fn_list else processed_seg
                    seg_vector = relation_retriever.index.reconstruct(rela_fn_to_faiss_index[seg_fn])
                    rela_similarity = [(rela, calculate_rela_similarity(seg_vector, rela)) for rela in possible_rela if rela in wikidata_mid_to_fn]
                    rela_similarity.sort(key=lambda x: x[1], reverse=True)
                    rela_replace_dict[j] = [rela for rela, score in rela_similarity]
        if len(rela_replace_dict) > 4:
            top_k = 1
        elif len(rela_replace_dict) > 2:
            top_k = 1
        else:
            top_k = 1

        for j in rela_replace_dict:
            rela_replace_dict[j] = rela_replace_dict[j][:top_k]
        
        # print({id: [wikidata_mid_to_fn[mid] for mid in mids] for id, mids in rela_replace_dict.items()})

        combinations_rela = list(rela_replace_dict.values())
        all_iters_rela = list(itertools.product(*combinations_rela))
        rela_index = list(rela_replace_dict.keys())
        for iter_rela in all_iters_rela:
            for k in range(len(iter_rela)):
                cur_rela = expression_segment[rela_index[k]]
                suffix = ')' * (len(cur_rela) - len(cur_rela.strip(')')))
                expression_segment_copy[rela_index[k]] = iter_rela[k] + suffix
            final = " ".join(expression_segment_copy)
            added = add_reverse(final) # 反转关系生成变体

            # 遍历added，首次能够查询到结果时，返回查询结果
            for exp in added:
                # print(exp)
                if type_replace_dict:
                    try:
                        sparql = expression_to_sparql(exp)
                    except ParseError:
                        return '', query_count
                    sparql = sparql.replace('SELECT ?x', f'SELECT DISTINCT {' '.join(type_replace_dict.values())}', 1)
                    possible_types = execute_query(sparql, multi_var=True)
                    # print([[wikidata_mid_to_fn[mid] for mid in binding] for binding in possible_types])
                    if isinstance(possible_types, list) and not possible_types or not possible_types[0]:
                        continue
                    query_count += 1
                    indexes = list(type_replace_dict.keys())
                    for type_id in range(len(type_replace_dict)):
                        index = indexes[type_id]
                        seg = expression_segment[index]
                        processed_seg = seg.strip(')')
                        possible_type = set([binding[type_id] for binding in possible_types])
                        seg_fn = type_retriever.semantic_search(processed_seg)[0][2] if processed_seg not in type_retriever.fn_list else processed_seg
                        seg_vector = type_retriever.index.reconstruct(type_fn_to_faiss_index[seg_fn])
                        type_similarity = [(typ, calculate_type_similarity(seg_vector, typ)) for typ in possible_type if typ in wikidata_mid_to_fn]
                        if not type_similarity:
                            exp = ''
                            break
                        # print([(wikidata_mid_to_fn[mid], score) for mid, score in type_similarity])
                        most_similar_type, highest_similarity = max(type_similarity, key=lambda x: x[1])
                        possible_types = [binding for binding in possible_types if binding[type_id] == most_similar_type]
                        exp = exp.replace(f'?t{type_id + 1}', most_similar_type)
                sparql = expression_to_sparql(exp)
                answer = execute_query(sparql)
                query_count += 1
                if isinstance(answer, bool) or answer:
                    results.append(exp)
                    if len(results) == num_variants:
                        return results, query_count
    # top_k linking failed
    if not results:
        results = [sub_fn_to_mid(s_expression)]
    return results, query_count

# %%
for i, qa in enumerate(test_data):
    print('gold cores:')
    for j, core in enumerate(qa['s_expression_cores']):
        print(qa['s_expression_cores_fn'][j])
    print()

    print('predicted_cores:')
    for core in qa['predicted_cores']:
        print(core)
    print()

    print('calibrated cores:') 
    qa['calibrated_cores'] = []
    qa['calibrated_cores_fn'] = []
    qa['sparql_attempt_count'] = 0
    for core in qa['predicted_cores']:
        if not is_close(core):
            core = fix_core(core)
        candidates, query_count = bound_to_existed(core)
        for calibrated_core in candidates:
            calibrated_core_core_fn = sub_mid_to_fn(calibrated_core)
            print(calibrated_core_core_fn)
            qa['calibrated_cores'].append(calibrated_core)
            qa['calibrated_cores_fn'].append(calibrated_core_core_fn)
    qa['sparql_attempt_count'] += query_count
    print()
    print('--------------------------------')
    print()

json.dump(test_data, open(f'output/{exp_name}/calibrated_cores.json', 'w'), indent=2)
# Out:
# gold cores:
# (AND (JOIN (R father) Ludovico_II,_Marquess_of_Saluzzo) (JOIN instance_of common_name))
#
# predicted_cores:
# (AND (JOIN (R father) Ludovico_II,_Marquess_of_Saluzzo) (JOIN sex_or_gender Male))
#
# calibrated cores:
# (AND (JOIN (R father) Ludovico_II,_Marquess_of_Saluzzo) (JOIN sex_or_gender Male))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R main_subject) Lessons_of_a_Dream) (JOIN instance_of sport))
#
# predicted_cores:
# (AND (JOIN main_subject Lessons_of_a_Dream) (JOIN instance_of concept))
#
# calibrated cores:
# (AND (JOIN (R main_subject) Lessons_of_a_Dream) (JOIN instance_of sport))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R member_of) Chris_Broderick) (JOIN instance_of musical_ensemble))
#
# predicted_cores:
# (AND (JOIN (R member_of) Chris_Broderick) (JOIN instance_of musical_ensemble))
#
# calibrated cores:
# (AND (JOIN (R member_of) Chris_Broderick) (JOIN instance_of musical_ensemble))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R place_of_death) Lázaro_Bardón) (JOIN instance_of political_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R place_of_death) Lázaro_Bardón) (JOIN instance_of political_territory))
#
# calibrated cores:
# (AND (JOIN (R place_of_death) Lázaro_Bardón) (JOIN instance_of political_territorial_entity))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R sex_or_gender) Émile_Forsanz) (JOIN instance_of sex))
#
# predicted_cores:
# (AND (JOIN (R sex_or_gender) Émile_Forsanz) (JOIN instance_of sex))
#
# calibrated cores:
# (AND (JOIN (R sex_or_gender) Émile_Forsanz) (JOIN instance_of sex))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R sex_or_gender) Michael_Brun) (JOIN instance_of sex))
#
# predicted_cores:
# (AND (JOIN (R sex_or_gender) Michael_Brun) (JOIN instance_of sex))
#
# calibrated cores:
# (AND (JOIN (R sex_or_gender) Michael_Brun) (JOIN instance_of sex))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R noble_title) Willem_Caspar_de_Jonge) (JOIN instance_of position))
#
# predicted_cores:
# (AND (JOIN (R noble_title) Willem_Caspar_de_Jonge) (JOIN instance_of noble_title))
#
# calibrated cores:
# (AND (JOIN (R noble_title) Willem_Caspar_de_Jonge) (JOIN instance_of position))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R award_received) Vladimir_von_Manstein) (JOIN instance_of award))
#
# predicted_cores:
# (AND (JOIN (R award_received) Vladimir_von_Manstein) (JOIN instance_of award))
#
# calibrated cores:
# (AND (JOIN (R award_received) Vladimir_von_Manstein) (JOIN instance_of award))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R occupation) Lau_Kar-leung) (JOIN instance_of profession))
#
# predicted_cores:
# (AND (JOIN (R occupation) Lau_Kar-leung) (JOIN instance_of occupation))
#
# calibrated cores:
# (AND (JOIN (R occupation) Lau_Kar-leung) (JOIN instance_of occupation))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R languages_spoken,_written_or_signed) Carlos_Santos) (JOIN instance_of language))
#
# predicted_cores:
# (AND (JOIN (R native_language) Carlos_Santos) (JOIN instance_of language))
#
# calibrated cores:
# (AND (JOIN cast_member Carlos_Santos) (JOIN instance_of work_of_art))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R cast_member) Pardonnez-moi) (JOIN instance_of common_name))
#
# predicted_cores:
# (AND (JOIN (R cast_member) Pardonnez-moi) (JOIN instance_of common_name))
#
# calibrated cores:
# (AND (JOIN (R cast_member) Pardonnez-moi) (JOIN instance_of common_name))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R country) Prignano_Cilento) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R country_of_citizenship) Prignano_Cilento) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# calibrated cores:
# (AND (JOIN (R country) Prignano_Cilento) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R cast_member) Leroy_&_Stitch) (JOIN instance_of common_name))
#
# predicted_cores:
# (AND (JOIN (R cast_member) Leroy_&_Stitch) (JOIN instance_of common_name))
#
# calibrated cores:
# (AND (JOIN (R cast_member) Leroy_&_Stitch) (JOIN instance_of common_name))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R place_of_birth) Diego_Terrazas) (JOIN instance_of administrative_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R place_of_birth) Diego_Terrazas) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# calibrated cores:
# (AND (JOIN (R place_of_birth) Diego_Terrazas) (JOIN instance_of administrative_territorial_entity))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R participant_in) Ilian_Iliev) (JOIN instance_of recurring_event))
#
# predicted_cores:
# (AND (JOIN (R participant) Ilian_Iliev) (JOIN instance_of recurring_event))
#
# calibrated cores:
# (AND (JOIN (R participant_in) Ilian_Iliev) (JOIN instance_of recurring_event))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R genre) Love_Italian_Style) (JOIN instance_of literary_genre))
#
# predicted_cores:
# (AND (JOIN (R genre) Love_Italian_Style) (JOIN instance_of genre))
#
# calibrated cores:
# (AND (JOIN (R genre) Love_Italian_Style) (JOIN instance_of literary_genre))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R place_of_birth) George_Ker) (JOIN instance_of administrative_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R place_of_birth) George_Ker) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# calibrated cores:
# (AND (JOIN (R place_of_birth) George_Ker) (JOIN instance_of administrative_territorial_entity))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R work_location) Antoni_Rosal_i_Sala) (JOIN instance_of administrative_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R work_location) Antoni_Rosal_i_Sala) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# calibrated cores:
# (AND (JOIN (R work_location) Antoni_Rosal_i_Sala) (JOIN instance_of administrative_territorial_entity))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R languages_spoken,_written_or_signed) Kathleen_Blanco) (JOIN instance_of language))
#
# predicted_cores:
# (AND (JOIN (R native_language) Kathleen_Blanco) (JOIN instance_of language))
#
# calibrated cores:
# (AND (JOIN (R native_language) Kathleen_Blanco) (JOIN instance_of language))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R religion_or_worldview) Adolf_Fritzen) (JOIN instance_of Christian_denomination))
#
# predicted_cores:
# (AND (JOIN (R religion) Adolf_Fritzen) (JOIN instance_of religion))
#
# calibrated cores:
# (AND (JOIN (R religious_name) Adolf_Fritzen) (JOIN instance_of religion))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R member_of_political_party) Ray_Franz) (JOIN instance_of political_organization))
#
# predicted_cores:
# (AND (JOIN (R member_of_political_party) Ray_Franz) (JOIN instance_of political_party))
#
# calibrated cores:
# (AND (JOIN (R instance_of) Ray_Franz) (JOIN instance_of web_page))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R composer) A_Friend_Will_Come_Tonight) (JOIN instance_of common_name))
#
# predicted_cores:
# (AND (JOIN composer A_Friend_Will_Come_Tonight) (JOIN instance_of common_name))
#
# calibrated cores:
# (AND (JOIN (R composer) A_Friend_Will_Come_Tonight) (JOIN instance_of common_name))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R sex_or_gender) Jerry_Jones) (JOIN instance_of sex))
#
# predicted_cores:
# (AND (JOIN (R sex_or_gender) Jerry_Jones) (JOIN instance_of sex))
#
# calibrated cores:
# (AND (JOIN (R sex_or_gender) Jerry_Jones) (JOIN instance_of sex))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R languages_spoken,_written_or_signed) Roger_Handasyd) (JOIN instance_of language))
#
# predicted_cores:
# (AND (JOIN (R languages_spoken,_written_or_signed) Roger_Handasyd) (JOIN instance_of language))
#
# calibrated cores:
# (AND (JOIN (R languages_spoken,_written_or_signed) Roger_Handasyd) (JOIN instance_of language))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R place_of_birth) Blas_Irala) (JOIN instance_of second-level_administrative_country_subdivision))
#
# predicted_cores:
# (AND (JOIN (R place_of_birth) Blas_Irala) (JOIN instance_of location))
#
# calibrated cores:
# (AND (JOIN (R place_of_birth) Blas_Irala) (JOIN instance_of second-level_administrative_country_subdivision))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R sport) Vyacheslav_Lyskin) (JOIN instance_of sport))
#
# predicted_cores:
# (AND (JOIN (R sport) Vyacheslav_Lyskin) (JOIN instance_of sport))
#
# calibrated cores:
# (AND (JOIN (R sport) Vyacheslav_Lyskin) (JOIN instance_of sport))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R molecular_function) DNA_ligase_(NAD+)____FP1847) (JOIN instance_of chemical_bond))
#
# predicted_cores:
# (AND (JOIN (R molecular_function) DNA_ligase_(NAD+)_FP1847) (JOIN instance_of chemical_bond))
#
# calibrated cores:
# (AND (JOIN (R molecular_function) DNA_ligase_(NAD+)____FP1847) (JOIN instance_of chemical_bond))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R family) Ernest,_Duke_of_Opava) (JOIN instance_of noble_family))
#
# predicted_cores:
# (AND (JOIN (R member_of) Ernest,_Duke_of_Opava) (JOIN instance_of dynasty))
#
# calibrated cores:
# (AND (JOIN (R instance_of) Ernest,_Duke_of_Opava) (JOIN instance_of identifier))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R molecular_function) Methylcrotonoyl-CoA_carboxylase_subunit_alpha,_mitochondrial) (JOIN instance_of chemical_bond))
#
# predicted_cores:
# (AND (JOIN (R molecular_function) Methylcrotonoyl-CoA_carboxylase_subunit_alpha,_mitochondrial) (JOIN instance_of molecular_function))
#
# calibrated cores:
# (AND (JOIN (R molecular_function) Methylcrotonoyl-CoA_carboxylase_subunit_alpha,_mitochondrial) (JOIN instance_of chemical_bond))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R cast_member) Red_Like_the_Sky) (JOIN instance_of common_name))
#
# predicted_cores:
# (AND (JOIN cast_member Red_Like_the_Sky) (JOIN instance_of common_name))
#
# calibrated cores:
# (AND (JOIN (R cast_member) Red_Like_the_Sky) (JOIN instance_of common_name))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R spouse) Bożena_Pytel) (JOIN instance_of common_name))
#
# predicted_cores:
# (AND (JOIN (R spouse) Bożena_Pytel) (JOIN instance_of common_name))
#
# calibrated cores:
# (AND (JOIN (R spouse) Bożena_Pytel) (JOIN instance_of common_name))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R languages_spoken,_written_or_signed) Elisa_Aguilar) (JOIN instance_of language))
#
# predicted_cores:
# (AND (JOIN (R native_language) Elisa_Aguilar) (JOIN instance_of language))
#
# calibrated cores:
# (AND (JOIN (R languages_spoken,_written_or_signed) Elisa_Aguilar) (JOIN instance_of language))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R encoded_by) Disintegrin_and_metalloproteinase_domain-containing_protein_1a) (JOIN instance_of nucleic_acid_sequence))
#
# predicted_cores:
# (AND (JOIN (R encoded_by) Disintegrin_and_metalloproteinase_domain-containing_protein_1a) (JOIN instance_of gene))
#
# calibrated cores:
# (AND (JOIN (R encoded_by) Disintegrin_and_metalloproteinase_domain-containing_protein_1a) (JOIN instance_of nucleic_acid_sequence))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R place_of_birth) Gottfried_Grünewald) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R place_of_birth) Gottfried_Grünewald) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# calibrated cores:
# (AND (JOIN (R place_of_birth) Gottfried_Grünewald) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R sport) Joe_Cockroft) (JOIN instance_of sport))
#
# predicted_cores:
# (AND (JOIN (R participant_of) Joe_Cockroft) (JOIN instance_of event))
#
# calibrated cores:
# (AND (JOIN (R participant) Joe_Cockroft) (JOIN instance_of event))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R occupation) Christian_Ernst_von_Windheim) (JOIN instance_of occupation))
#
# predicted_cores:
# (AND (JOIN (R occupation) Christian_Ernst_von_Windheim) (JOIN instance_of occupation))
#
# calibrated cores:
# (AND (JOIN (R occupation) Christian_Ernst_von_Windheim) (JOIN instance_of occupation))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R sex_or_gender) Tan_Malaka) (JOIN instance_of sex))
#
# predicted_cores:
# (AND (JOIN (R sex_or_gender) Tan_Malaka) (JOIN instance_of sex))
#
# calibrated cores:
# (AND (JOIN (R sex_or_gender) Tan_Malaka) (JOIN instance_of sex))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R place_of_death) Alfred_Stuiber) (JOIN instance_of administrative_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R place_of_death) Alfred_Stuiber) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# calibrated cores:
# (AND (JOIN (R place_of_death) Alfred_Stuiber) (JOIN instance_of administrative_territorial_entity))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R place_of_birth) Gerhard_Berger) (JOIN instance_of administrative_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R place_of_birth) Gerhard_Berger) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# calibrated cores:
# (AND (JOIN (R place_of_birth) Gerhard_Berger) (JOIN instance_of administrative_territorial_entity))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R place_of_birth) Heinz_Flotho) (JOIN instance_of human_settlement))
#
# predicted_cores:
# (AND (JOIN (R place_of_birth) Heinz_Flotho) (JOIN instance_of human_settlement))
#
# calibrated cores:
# (AND (JOIN (R place_of_birth) Heinz_Flotho) (JOIN instance_of human_settlement))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R place_of_birth) Paul_Nadar) (JOIN instance_of administrative_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R place_of_birth) Paul_Nadar) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# calibrated cores:
# (AND (JOIN (R place_of_birth) Paul_Nadar) (JOIN instance_of administrative_territorial_entity))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R child) Alan_Hale) (JOIN instance_of common_name))
#
# predicted_cores:
# (AND (JOIN (R child) Alan_Hale) (JOIN instance_of common_name))
#
# calibrated cores:
# (AND (JOIN (R child) Alan_Hale) (JOIN instance_of common_name))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R member_of_sports_team) Hazem_Mahamid) (JOIN instance_of national_sports_team))
#
# predicted_cores:
# (AND (JOIN (R member_of) Hazem_Mahamid) (JOIN instance_of organization))
#
# calibrated cores:
# (AND (JOIN (R member_of_sports_team) Hazem_Mahamid) (JOIN instance_of national_sports_team))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R occupation) Juan_Ramón_Vidal) (JOIN instance_of profession))
#
# predicted_cores:
# (AND (JOIN (R occupation) Juan_Ramón_Vidal) (JOIN instance_of occupation))
#
# calibrated cores:
# (AND (JOIN (R occupation) Juan_Ramón_Vidal) (JOIN instance_of occupation))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R member_of_political_party) Donald_William_Cameron) (JOIN instance_of political_organization))
#
# predicted_cores:
# (AND (JOIN (R member_of_political_party) Donald_William_Cameron) (JOIN instance_of political_party))
#
# calibrated cores:
# (AND (JOIN (R member_of_political_party) Donald_William_Cameron) (JOIN instance_of political_organization))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R position_held) Bill_Blythe) (JOIN instance_of occupation))
#
# predicted_cores:
# (AND (JOIN (R position_held) Bill_Blythe) (JOIN instance_of position))
#
# calibrated cores:
# (AND (JOIN (R position_held) Bill_Blythe) (JOIN instance_of occupation))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R place_of_birth) Robert_Naegele) (JOIN instance_of administrative_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R place_of_birth) Robert_Naegele) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# calibrated cores:
# (AND (JOIN (R place_of_birth) Robert_Naegele) (JOIN instance_of administrative_territorial_entity))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R member_of_sports_team) Tim_Bergland) (JOIN instance_of sports_team))
#
# predicted_cores:
# (AND (JOIN (R member_of_sports_team) Tim_Bergland) (JOIN instance_of sports_team))
#
# calibrated cores:
# (AND (JOIN (R member_of_sports_team) Tim_Bergland) (JOIN instance_of sports_team))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R country_of_citizenship) Jimmy_Bran) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R country_of_citizenship) Jimmy_Bran) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# calibrated cores:
# (AND (JOIN (R country_of_citizenship) Jimmy_Bran) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R biological_process) Olfactory_receptor_1N2) (JOIN instance_of process))
#
# predicted_cores:
# (AND (JOIN (R involved_in) Olfactory_receptor_1N2) (JOIN instance_of biological_process))
#
# calibrated cores:
# (AND (JOIN (R found_in_taxon) Olfactory_receptor_1N2) (JOIN instance_of taxon))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R languages_spoken,_written_or_signed) Roberto_Soffritti) (JOIN instance_of language))
#
# predicted_cores:
# (AND (JOIN (R native_language) Roberto_Soffritti) (JOIN instance_of language))
#
# calibrated cores:
# (AND (JOIN (R native_language) Roberto_Soffritti) (JOIN instance_of language))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R work_location) Bent_Hindrup_Andersen) (JOIN instance_of city))
#
# predicted_cores:
# (AND (JOIN (R place_of_work) Bent_Hindrup_Andersen) (JOIN instance_of location))
#
# calibrated cores:
# (AND (JOIN (R work_location) Bent_Hindrup_Andersen) (JOIN instance_of administrative_territorial_entity))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R military_branch) William_Dickson) (JOIN instance_of military_branch))
#
# predicted_cores:
# (AND (JOIN (R member_of) William_Dickson) (JOIN instance_of military_branch))
#
# calibrated cores:
# (AND (JOIN (R country_of_citizenship) William_Dickson) (JOIN instance_of state))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R sex_or_gender) Kenneth_Halverson) (JOIN instance_of sex))
#
# predicted_cores:
# (AND (JOIN (R sex_or_gender) Kenneth_Halverson) (JOIN instance_of sex))
#
# calibrated cores:
# (AND (JOIN (R sex_or_gender) Kenneth_Halverson) (JOIN instance_of sex))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R position_held) William_B._Read) (JOIN instance_of occupation))
#
# predicted_cores:
# (AND (JOIN (R position_held) William_B._Read) (JOIN instance_of position))
#
# calibrated cores:
# (AND (JOIN (R position_held) William_B._Read) (JOIN instance_of occupation))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R biological_process) riboflavin_biosynthesis_bifunctional_riboflavin_kinase/FAD_synthetase_RibF____THEYE_A0704) (JOIN instance_of biological_process))
#
# predicted_cores:
# (AND (JOIN (R involved_in) riboflavin_biosynthesis_bifunctional_riboflavin_kinase/FAD_synthetase_RibF____THEYE_A0704) (JOIN instance_of biological_process))
#
# calibrated cores:
# (AND (JOIN (R found_in_taxon) riboflavin_biosynthesis_bifunctional_riboflavin_kinase/FAD_synthetase_RibF____THEYE_A0704) (JOIN instance_of taxon))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R member_of_political_party) Olof_Andreasson) (JOIN instance_of political_organization))
#
# predicted_cores:
# (AND (JOIN (R member_of_political_party) Olof_Andreasson) (JOIN instance_of political_party))
#
# calibrated cores:
# (AND (JOIN (R member_of_political_party) Olof_Andreasson) (JOIN instance_of political_organization))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R country_of_citizenship) Ingemar_Eliasson) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R country_of_citizenship) Ingemar_Eliasson) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# calibrated cores:
# (AND (JOIN (R country_of_citizenship) Ingemar_Eliasson) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R genre) Maria_Teresa_Llorens_i_Crusat) (JOIN instance_of work_of_art))
#
# predicted_cores:
# (AND (JOIN (R genre) Maria_Teresa_Llorens_i_Crusat) (JOIN instance_of work_of_art))
#
# calibrated cores:
# (AND (JOIN (R genre) Maria_Teresa_Llorens_i_Crusat) (JOIN instance_of work_of_art))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R country_of_citizenship) Nancy_Munoz) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R country_of_citizenship) Nancy_Munoz) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# calibrated cores:
# (AND (JOIN (R country_of_citizenship) Nancy_Munoz) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R conflict) Hans_Heidtmann) (JOIN instance_of war))
#
# predicted_cores:
# (AND (JOIN (R participant_in) Hans_Heidtmann) (JOIN instance_of battle))
#
# calibrated cores:
# (AND (JOIN (R participant_in) Hans_Heidtmann) (JOIN instance_of battle))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R place_of_birth) Franco_Fasano) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R place_of_birth) Franco_Fasano) (JOIN instance_of city))
#
# calibrated cores:
# (AND (JOIN (R place_of_birth) Franco_Fasano) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R occupation) Ha_Si_Lao) (JOIN instance_of concept))
#
# predicted_cores:
# (AND (JOIN (R occupation) Ha_Si_Lao) (JOIN instance_of occupation))
#
# calibrated cores:
# (AND (JOIN (R occupation) Ha_Si_Lao) (JOIN instance_of concept))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R occupation) Joop_van_Maurik) (JOIN instance_of occupation))
#
# predicted_cores:
# (AND (JOIN (R occupation) Joop_van_Maurik) (JOIN instance_of occupation))
#
# calibrated cores:
# (AND (JOIN (R occupation) Joop_van_Maurik) (JOIN instance_of occupation))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R place_of_birth) Gustav_Franz_Hüttig) (JOIN instance_of administrative_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R place_of_birth) Gustav_Franz_Hüttig) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# calibrated cores:
# (AND (JOIN (R place_of_birth) Gustav_Franz_Hüttig) (JOIN instance_of administrative_territorial_entity))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R occupation) Gregorio_Allegri) (JOIN instance_of occupation))
#
# predicted_cores:
# (AND (JOIN (R occupation) Gregorio_Allegri) (JOIN instance_of occupation))
#
# calibrated cores:
# (AND (JOIN (R occupation) Gregorio_Allegri) (JOIN instance_of occupation))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R biological_process) T-cell_surface_glycoprotein_CD1a) (JOIN instance_of biological_process))
#
# predicted_cores:
# (AND (JOIN (R involved_in) T-cell_surface_glycoprotein_CD1a) (JOIN instance_of biological_process))
#
# calibrated cores:
# (AND (JOIN (R found_in_taxon) T-cell_surface_glycoprotein_CD1a) (JOIN instance_of taxon))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R member_of_political_party) H._F._B._Lynch) (JOIN instance_of political_organization))
#
# predicted_cores:
# (AND (JOIN (R member_of_political_party) H._F._B._Lynch) (JOIN instance_of political_party))
#
# calibrated cores:
# (AND (JOIN (R member_of_political_party) H._F._B._Lynch) (JOIN instance_of political_organization))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R languages_spoken,_written_or_signed) Gilbert_Richard_Redgrave) (JOIN instance_of language))
#
# predicted_cores:
# (AND (JOIN (R languages_spoken,_written_or_signed) Gilbert_Richard_Redgrave) (JOIN instance_of language))
#
# calibrated cores:
# (AND (JOIN (R languages_spoken,_written_or_signed) Gilbert_Richard_Redgrave) (JOIN instance_of language))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R occupation) Iliko_Sukhishvili) (JOIN instance_of occupation))
#
# predicted_cores:
# (AND (JOIN (R occupation) Iliko_Sukhishvili) (JOIN instance_of occupation))
#
# calibrated cores:
# (AND (JOIN (R occupation) Iliko_Sukhishvili) (JOIN instance_of occupation))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R encoded_by) Complement_component_C8_beta_chain) (JOIN instance_of nucleic_acid_sequence))
#
# predicted_cores:
# (AND (JOIN (R encoded_by) Complement_component_C8_beta_chain) (JOIN instance_of gene))
#
# calibrated cores:
# (AND (JOIN (R encoded_by) Complement_component_C8_beta_chain) (JOIN instance_of nucleic_acid_sequence))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R encoded_by) acylglycerol_lipase_YKL094W) (JOIN instance_of nucleic_acid_sequence))
#
# predicted_cores:
# (AND (JOIN (R encoded_by) acylglycerol_lipase_YKL094W) (JOIN instance_of nucleic_acid_sequence))
#
# calibrated cores:
# (AND (JOIN (R encoded_by) acylglycerol_lipase_YKL094W) (JOIN instance_of nucleic_acid_sequence))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R sport) Georg_Zellhofer) (JOIN instance_of sport))
#
# predicted_cores:
# (AND (JOIN (R sport) Georg_Zellhofer) (JOIN instance_of sport))
#
# calibrated cores:
# (AND (JOIN (R sport) Georg_Zellhofer) (JOIN instance_of sport))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R occupation) Arthur_Salz) (JOIN instance_of occupation))
#
# predicted_cores:
# (AND (JOIN (R occupation) Arthur_Salz) (JOIN instance_of occupation))
#
# calibrated cores:
# (AND (JOIN (R occupation) Arthur_Salz) (JOIN instance_of occupation))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R award_received) William_Fitzherbert) (JOIN instance_of chivalric_order))
#
# predicted_cores:
# (AND (JOIN (R award_received) William_Fitzherbert) (JOIN instance_of award))
#
# calibrated cores:
# (AND (JOIN (R award_received) William_Fitzherbert) (JOIN instance_of award))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R occupation) Matteo_Guardalben) (JOIN instance_of occupation))
#
# predicted_cores:
# (AND (JOIN (R occupation) Matteo_Guardalben) (JOIN instance_of occupation))
#
# calibrated cores:
# (AND (JOIN (R occupation) Matteo_Guardalben) (JOIN instance_of occupation))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R occupation) Jean-Baptiste-Alexis_Chambon) (JOIN instance_of occupation))
#
# predicted_cores:
# (AND (JOIN (R occupation) Jean-Baptiste-Alexis_Chambon) (JOIN instance_of occupation))
#
# calibrated cores:
# (AND (JOIN (R occupation) Jean-Baptiste-Alexis_Chambon) (JOIN instance_of occupation))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R country_of_origin) Retrato_de_Familia) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R country_of_origin) Retrato_de_Familia) (JOIN instance_of territorial_entity))
#
# calibrated cores:
# (AND (JOIN (R country_of_origin) Retrato_de_Familia) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R country_of_citizenship) Mickey_Bass) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R country_of_citizenship) Mickey_Bass) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# calibrated cores:
# (AND (JOIN (R country_of_citizenship) Mickey_Bass) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R position_held) Micaela_Campana) (JOIN instance_of occupation))
#
# predicted_cores:
# (AND (JOIN (R position_held) Micaela_Campana) (JOIN instance_of position))
#
# calibrated cores:
# (AND (JOIN (R position_held) Micaela_Campana) (JOIN instance_of occupation))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R educated_at) Harold_Ballard) (JOIN instance_of educational_institution))
#
# predicted_cores:
# (AND (JOIN (R educated_at) Harold_Ballard) (JOIN instance_of educational_institution))
#
# calibrated cores:
# (AND (JOIN (R educated_at) Harold_Ballard) (JOIN instance_of educational_institution))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R occupation) Marinus_van_IJzendoorn) (JOIN instance_of occupation))
#
# predicted_cores:
# (AND (JOIN (R occupation) Marinus_van_IJzendoorn) (JOIN instance_of occupation))
#
# calibrated cores:
# (AND (JOIN (R occupation) Marinus_van_IJzendoorn) (JOIN instance_of occupation))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R position_held) Manuel_Ruiz_Maya) (JOIN instance_of occupation))
#
# predicted_cores:
# (AND (JOIN (R position_held) Manuel_Ruiz_Maya) (JOIN instance_of occupation))
#
# calibrated cores:
# (AND (JOIN (R position_held) Manuel_Ruiz_Maya) (JOIN instance_of occupation))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R sex_or_gender) Cosimo_Alessandro_Collini) (JOIN instance_of sex))
#
# predicted_cores:
# (AND (JOIN (R sex_or_gender) Cosimo_Alessandro_Collini) (JOIN instance_of sex))
#
# calibrated cores:
# (AND (JOIN (R sex_or_gender) Cosimo_Alessandro_Collini) (JOIN instance_of sex))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R molecular_function) mercury_resistance_operon_protein_MerP____O3K_00420) (JOIN instance_of chemical_bond))
#
# predicted_cores:
# (AND (JOIN (R molecular_function) mercury_resistance_operon_protein_MerP_O3K_00420) (JOIN instance_of chemical_bond))
#
# calibrated cores:
# (AND (JOIN (R molecular_function) mercury_resistance_operon_protein_MerP____O3K_00420) (JOIN instance_of chemical_bond))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R occupation) Waris_Dirie) (JOIN instance_of occupation))
#
# predicted_cores:
# (AND (JOIN (R occupation) Waris_Dirie) (JOIN instance_of occupation))
#
# calibrated cores:
# (AND (JOIN (R occupation) Waris_Dirie) (JOIN instance_of occupation))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R place_of_birth) Edmund_Potrzebowski) (JOIN instance_of human_settlement))
#
# predicted_cores:
# (AND (JOIN (R place_of_birth) Edmund_Potrzebowski) (JOIN instance_of human_settlement))
#
# calibrated cores:
# (AND (JOIN (R place_of_birth) Edmund_Potrzebowski) (JOIN instance_of human_settlement))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R member_of_sports_team) Hardi_Bujang) (JOIN instance_of national_sports_team))
#
# predicted_cores:
# (AND (JOIN (R member_of) Hardi_Bujang) (JOIN instance_of organization))
#
# calibrated cores:
# (AND (JOIN (R member_of_sports_team) Hardi_Bujang) (JOIN instance_of national_sports_team))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R country_of_citizenship) Morton_Mandel) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R country_of_citizenship) Morton_Mandel) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# calibrated cores:
# (AND (JOIN (R country_of_citizenship) Morton_Mandel) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R cell_component) Gap_junction_beta-7_protein) (JOIN instance_of cellular_component))
#
# predicted_cores:
# (AND (JOIN (R has_part) Gap_junction_beta-7_protein) (JOIN instance_of protein))
#
# calibrated cores:
# (AND (JOIN (R has_part(s)) Gap_junction_beta-7_protein) (JOIN instance_of part))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R sex_or_gender) Benet_Tugues_i_Boliart) (JOIN instance_of sex))
#
# predicted_cores:
# (AND (JOIN (R sex_or_gender) Benet_Tugues_i_Boliart) (JOIN instance_of sex))
#
# calibrated cores:
# (AND (JOIN (R sex_or_gender) Benet_Tugues_i_Boliart) (JOIN instance_of sex))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R place_of_death) Juan_Vázquez_de_Molina) (JOIN instance_of administrative_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R place_of_death) Juan_Vázquez_de_Molina) (JOIN instance_of location))
#
# calibrated cores:
# (AND (JOIN (R place_of_death) Juan_Vázquez_de_Molina) (JOIN instance_of administrative_territorial_entity))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R member_of_political_party) Jane_Kennedy) (JOIN instance_of political_organization))
#
# predicted_cores:
# (AND (JOIN (R member_of_political_party) Jane_Kennedy) (JOIN instance_of political_party))
#
# calibrated cores:
# (AND (JOIN (R family_name) Jane_Kennedy) (JOIN instance_of name))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R sister) Gleb_Baklanov) (JOIN instance_of common_name))
#
# predicted_cores:
# (AND (JOIN sibling Gleb_Baklanov) (JOIN instance_of common_name))
#
# calibrated cores:
# (AND (JOIN brother Gleb_Baklanov) (JOIN instance_of common_name))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R found_in_taxon) Protein_S-Myc) (JOIN instance_of taxon))
#
# predicted_cores:
# (AND (JOIN (R found_in_taxon) Protein_S-Myc) (JOIN instance_of taxon))
#
# calibrated cores:
# (AND (JOIN (R found_in_taxon) Protein_S-Myc) (JOIN instance_of taxon))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R sex_or_gender) Ivan_Marconi) (JOIN instance_of sex))
#
# predicted_cores:
# (AND (JOIN (R sex_or_gender) Ivan_Marconi) (JOIN instance_of sex))
#
# calibrated cores:
# (AND (JOIN (R sex_or_gender) Ivan_Marconi) (JOIN instance_of sex))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R member_of_sports_team) Diyan_Donchev) (JOIN instance_of national_sports_team))
#
# predicted_cores:
# (AND (JOIN (R member_of) Diyan_Donchev) (JOIN instance_of organization))
#
# calibrated cores:
# (AND (JOIN (R member_of_sports_team) Diyan_Donchev) (JOIN instance_of national_sports_team))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R member_of_political_party) Joachim_Dirschka) (JOIN instance_of political_party))
#
# predicted_cores:
# (AND (JOIN (R member_of_political_party) Joachim_Dirschka) (JOIN instance_of political_party))
#
# calibrated cores:
# (AND (JOIN (R member_of_political_party) Joachim_Dirschka) (JOIN instance_of political_party))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R award_received) José_Carrillo_de_Albornoz,_1st_Duke_of_Montemar) (JOIN instance_of chivalric_order))
#
# predicted_cores:
# (AND (JOIN (R award_received) José_Carrillo_de_Albornoz,_1st_Duke_of_Montemar) (JOIN instance_of award))
#
# calibrated cores:
# (AND (JOIN (R award_received) José_Carrillo_de_Albornoz,_1st_Duke_of_Montemar) (JOIN instance_of chivalric_order))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R country_of_citizenship) Shannon_May) (JOIN instance_of political_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R country_of_citizenship) Shannon_May) (JOIN instance_of political_territorial_entity))
#
# calibrated cores:
# (AND (JOIN (R country_of_citizenship) Shannon_May) (JOIN instance_of political_territorial_entity))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R occupation) Maximiliano_Calzada) (JOIN instance_of occupation))
#
# predicted_cores:
# (AND (JOIN (R occupation) Maximiliano_Calzada) (JOIN instance_of occupation))
#
# calibrated cores:
# (AND (JOIN (R occupation) Maximiliano_Calzada) (JOIN instance_of occupation))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R sister) Kingdon_Gould,_Jr) (JOIN instance_of common_name))
#
# predicted_cores:
# (AND (JOIN (R sibling) Kingdon_Gould,_Jr.) (JOIN instance_of common_name))
#
# calibrated cores:
# (AND (JOIN brother Kingdon_Gould,_Jr) (JOIN instance_of common_name))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R occupation) Constantine_of_Kostenets) (JOIN instance_of concept))
#
# predicted_cores:
# (AND (JOIN (R occupation) Constantine_of_Kostenets) (JOIN instance_of occupation))
#
# calibrated cores:
# (AND (JOIN (R occupation) Constantine_of_Kostenets) (JOIN instance_of occupation))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R country_of_origin) Erotica) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R country_of_origin) Erotica) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# calibrated cores:
# (AND (JOIN (R country_of_origin) Erotica) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R place_of_birth) André_Picard) (JOIN instance_of administrative_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R place_of_birth) André_Picard) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# calibrated cores:
# (AND (JOIN (R place_of_birth) André_Picard) (JOIN instance_of type_of_french_administrative_division))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R place_of_death) Fred_Kronström) (JOIN instance_of administrative_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R place_of_death) Fred_Kronström) (JOIN instance_of location))
#
# calibrated cores:
# (AND (JOIN (R place_of_death) Fred_Kronström) (JOIN instance_of administrative_territorial_entity))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R place_of_burial) Jonas_Offrell) (JOIN instance_of organization))
#
# predicted_cores:
# (AND (JOIN (R place_of_burial) Jonas_Offrell) (JOIN instance_of organization))
#
# calibrated cores:
# (AND (JOIN (R place_of_burial) Jonas_Offrell) (JOIN instance_of organization))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R place_of_birth) August_Malotki_von_Trzebiatowski) (JOIN instance_of human_settlement))
#
# predicted_cores:
# (AND (JOIN (R place_of_birth) August_Malotki_von_Trzebiatowski) (JOIN instance_of human_settlement))
#
# calibrated cores:
# (AND (JOIN (R place_of_birth) August_Malotki_von_Trzebiatowski) (JOIN instance_of human_settlement))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R country_of_citizenship) Patrick_Yetman) (JOIN instance_of political_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R country_of_citizenship) Patrick_Yetman) (JOIN instance_of political_territorial_entity))
#
# calibrated cores:
# (AND (JOIN (R country_of_citizenship) Patrick_Yetman) (JOIN instance_of political_territorial_entity))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R place_of_birth) Rose_Lavelle) (JOIN instance_of city))
#
# predicted_cores:
# (AND (JOIN (R place_of_birth) Rose_Lavelle) (JOIN instance_of city))
#
# calibrated cores:
# (AND (JOIN (R place_of_birth) Rose_Lavelle) (JOIN instance_of city))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R director_of_photography) Se_solicitan_modelos) (JOIN instance_of common_name))
#
# predicted_cores:
# (AND (JOIN (R cinematographer) Se_solicitan_modelos) (JOIN instance_of common_name))
#
# calibrated cores:
# (AND (JOIN (R director_of_photography) Se_solicitan_modelos) (JOIN instance_of common_name))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R participant) 1973_Tour_de_France) (JOIN instance_of common_name))
#
# predicted_cores:
# (AND (JOIN participant 1973_Tour_de_France) (JOIN instance_of artist))
#
# calibrated cores:
# (AND (JOIN (R participant) 1973_Tour_de_France) (JOIN instance_of common_name))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R languages_spoken,_written_or_signed) Edward_Hoagland) (JOIN instance_of language))
#
# predicted_cores:
# (AND (JOIN (R languages_written_spoken_or_signed) Edward_Hoagland) (JOIN instance_of language))
#
# calibrated cores:
# (AND (JOIN (R languages_spoken,_written_or_signed) Edward_Hoagland) (JOIN instance_of language))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R military_or_police_rank) Larry_D._James) (JOIN instance_of title))
#
# predicted_cores:
# (AND (JOIN (R military_rank) Larry_D._James) (JOIN instance_of title))
#
# calibrated cores:
# (AND (JOIN (R military_or_police_rank) Larry_D._James) (JOIN instance_of title))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R occupation) Claude_Lacaze) (JOIN instance_of occupation))
#
# predicted_cores:
# (AND (JOIN (R occupation) Claude_Lacaze) (JOIN instance_of occupation))
#
# calibrated cores:
# (AND (JOIN (R occupation) Claude_Lacaze) (JOIN instance_of occupation))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R occupation) Gene_Ellenson) (JOIN instance_of occupation))
#
# predicted_cores:
# (AND (JOIN (R occupation) Gene_Ellenson) (JOIN instance_of occupation))
#
# calibrated cores:
# (AND (JOIN (R occupation) Gene_Ellenson) (JOIN instance_of occupation))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R sex_or_gender) Eugène_Delaroue) (JOIN instance_of sex))
#
# predicted_cores:
# (AND (JOIN (R sex_or_gender) Eugène_Delaroue) (JOIN instance_of sex))
#
# calibrated cores:
# (AND (JOIN (R sex_or_gender) Eugène_Delaroue) (JOIN instance_of sex))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R country) Netvořice) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R located_in_the_administrative_territorial_entity) Netvořice) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# calibrated cores:
# (AND (JOIN (R located_in_the_administrative_territorial_entity) Netvořice) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R family_name) Zachary_James) (JOIN instance_of name))
#
# predicted_cores:
# (AND (JOIN (R name) Zachary_James) (JOIN instance_of name))
#
# calibrated cores:
# (AND (JOIN (R name) Zachary_James) (JOIN instance_of name))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R genre) I_Am_Twenty) (JOIN instance_of art_genre))
#
# predicted_cores:
# (AND (JOIN (R genre) I_Am_Twenty) (JOIN instance_of genre))
#
# calibrated cores:
# (AND (JOIN (R genre) I_Am_Twenty) (JOIN instance_of art_genre))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R country_of_citizenship) Sarawut_Masuk) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R country_of_citizenship) Sarawut_Masuk) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# calibrated cores:
# (AND (JOIN (R country_of_citizenship) Sarawut_Masuk) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R sport) Alfred_Leonard_Caiels) (JOIN instance_of sport))
#
# predicted_cores:
# (AND (JOIN (R sport) Alfred_Leonard_Caiels) (JOIN instance_of sport))
#
# calibrated cores:
# (AND (JOIN (R sport) Alfred_Leonard_Caiels) (JOIN instance_of sport))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R cell_component) thioredoxin_peroxidase_TSA1_YML028W) (JOIN instance_of part))
#
# predicted_cores:
# (AND (JOIN (R has_parts) thioredoxin_peroxidase_TSA1_YML028W) (JOIN instance_of molecular_component))
#
# calibrated cores:
# (AND (JOIN (R cell_component) thioredoxin_peroxidase_TSA1_YML028W) (JOIN instance_of part))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R ethnic_group) Christopher_Weeramantry) (JOIN instance_of people))
#
# predicted_cores:
# (AND (JOIN (R ethnicity) Christopher_Weeramantry) (JOIN instance_of ethnicity))
#
# calibrated cores:
# (AND (JOIN (R ethnic_group) Christopher_Weeramantry) (JOIN instance_of people))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R work_location) Johann_Friedrich_Müller) (JOIN instance_of city))
#
# predicted_cores:
# (AND (JOIN (R work_location) Johann_Friedrich_Müller) (JOIN instance_of city))
#
# calibrated cores:
# (AND (JOIN (R work_location) Johann_Friedrich_Müller) (JOIN instance_of city))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R found_in_taxon) Protein_Jade-3) (JOIN instance_of taxon))
#
# predicted_cores:
# (AND (JOIN (R found_in_taxon) Protein_Jade-3) (JOIN instance_of taxon))
#
# calibrated cores:
# (AND (JOIN (R found_in_taxon) Protein_Jade-3) (JOIN instance_of taxon))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R educated_at) Antara_Biswas) (JOIN instance_of university))
#
# predicted_cores:
# (AND (JOIN (R educated_at) Antara_Biswas) (JOIN instance_of educational_institution))
#
# calibrated cores:
# (AND (JOIN (R educated_at) Antara_Biswas) (JOIN instance_of university))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R student) Yokoyama_Taikan) (JOIN instance_of common_name))
#
# predicted_cores:
# (AND (JOIN (R student_of) Yokoyama_Taikan) (JOIN instance_of common_name))
#
# calibrated cores:
# (AND (JOIN (R student_of) Yokoyama_Taikan) (JOIN instance_of common_name))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R position_held) Ahmad_Sa'd) (JOIN instance_of occupation))
#
# predicted_cores:
# (AND (JOIN (R position_held) Ahmad_Sa'd) (JOIN instance_of position))
#
# calibrated cores:
# (AND (JOIN (R position_held) Ahmad_Sa'd) (JOIN instance_of occupation))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R sex_or_gender) David_Farr) (JOIN instance_of sex))
#
# predicted_cores:
# (AND (JOIN (R sex_or_gender) David_Farr) (JOIN instance_of sex))
#
# calibrated cores:
# (AND (JOIN (R instance_of) David_Farr) (JOIN instance_of web_page))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R place_of_birth) Thomas_Miller) (JOIN instance_of administrative_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R place_of_birth) Thomas_Miller) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# calibrated cores:
# (AND (JOIN (R place_of_birth) Thomas_Miller) (JOIN instance_of administrative_territorial_entity))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R place_of_death) Jiří_Karásek_ze_Lvovic) (JOIN instance_of administrative_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R place_of_death) Jiří_Karásek_ze_Lvovic) (JOIN instance_of location))
#
# calibrated cores:
# (AND (JOIN (R place_of_death) Jiří_Karásek_ze_Lvovic) (JOIN instance_of administrative_territorial_entity))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R occupation) Tinnapob_Srisathit) (JOIN instance_of occupation))
#
# predicted_cores:
# (AND (JOIN (R occupation) Tinnapob_Srisathit) (JOIN instance_of occupation))
#
# calibrated cores:
# (AND (JOIN (R occupation) Tinnapob_Srisathit) (JOIN instance_of occupation))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R father) Dave_McCloughan) (JOIN instance_of common_name))
#
# predicted_cores:
# (AND (JOIN (R father) Dave_McCloughan) (JOIN instance_of common_name))
#
# calibrated cores:
# (AND (JOIN (R father) Dave_McCloughan) (JOIN instance_of common_name))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R participant_in) Suzanne_Louis-Lane) (JOIN instance_of Badminton_at_the_Commonwealth_Games))
#
# predicted_cores:
# (AND (JOIN (R participant_of) Suzanne_Louis-Lane) (JOIN instance_of event))
#
# calibrated cores:
# (AND (JOIN participant Suzanne_Louis-Lane) (JOIN instance_of Welsh_International_Badminton_Championships))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R ethnic_group) Vahé_Oshagan) (JOIN instance_of people))
#
# predicted_cores:
# (AND (JOIN (R ethnic_group) Vahé_Oshagan) (JOIN instance_of ethnic_group))
#
# calibrated cores:
# (AND (JOIN (R ethnic_group) Vahé_Oshagan) (JOIN instance_of people))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R languages_spoken,_written_or_signed) Maximiliano_Oliva) (JOIN instance_of language))
#
# predicted_cores:
# (AND (JOIN (R languages_spoken,_written_or_signed) Maximiliano_Oliva) (JOIN instance_of language))
#
# calibrated cores:
# (AND (JOIN (R languages_spoken,_written_or_signed) Maximiliano_Oliva) (JOIN instance_of language))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R genre) Paul_Heaton) (JOIN instance_of concept))
#
# predicted_cores:
# (AND (JOIN (R genre) Paul_Heaton) (JOIN instance_of genre))
#
# calibrated cores:
# (AND (JOIN (R genre) Paul_Heaton) (JOIN instance_of concept))
#
# --------------------------------
#
# gold cores:
# ...
#
# predicted_cores:
# (AND (JOIN (R found_in_taxon) (JOIN instance_of nucleic_acid_sequence)) (JOIN instance_of infraspecific_name))
# (AND (JOIN found_in_taxon Salinibacter_ruber_DSM_13855) (JOIN instance_of nucleic_acid_sequence))
#
# calibrated cores:
# (AND (JOIN (R found_in_taxon) (JOIN instance_of nucleic_acid_sequence)) (JOIN instance_of infraspecific_name))
# (AND (JOIN found_in_taxon Salinibacter_ruber_DSM_13855) (JOIN instance_of nucleic_acid_sequence))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R field_of_work) (JOIN instance_of common_name)) (JOIN instance_of human_behaviour))
# (AND (JOIN field_of_work politics) (JOIN instance_of common_name))
#
# predicted_cores:
# (AND (JOIN (R behavior) (JOIN instance_of common_name)) (JOIN instance_of human_behavior))
# (AND (JOIN behavior politics) (JOIN instance_of common_name))
#
# calibrated cores:
# (AND (JOIN (R movement) (JOIN instance_of common_name)) (JOIN instance_of behavior))
# (AND (JOIN occupation politics) (JOIN instance_of common_name))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R sex_or_gender) (JOIN instance_of common_name)) (JOIN instance_of sex))
#
# predicted_cores:
# (AND (JOIN (R sex_or_gender) (JOIN instance_of common_name)) (JOIN instance_of sex))
# (AND (JOIN sex_or_gender female) (JOIN instance_of common_name))
#
# calibrated cores:
# (AND (JOIN (R sex_or_gender) (JOIN instance_of common_name)) (JOIN instance_of sex))
# (AND (JOIN sex_or_gender female) (JOIN instance_of common_name))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R country_of_origin) (JOIN instance_of release)) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R country_of_origin) (JOIN instance_of release)) (JOIN instance_of designation_for_an_administrative_territorial_entity))
# (AND (JOIN country_of_origin United_Kingdom) (JOIN instance_of release))
#
# calibrated cores:
# (AND (JOIN (R country_of_origin) (JOIN instance_of release)) (JOIN instance_of designation_for_an_administrative_territorial_entity))
# (AND (JOIN country_of_origin United_Kingdom) (JOIN instance_of release))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R sex_or_gender) (JOIN instance_of common_name)) (JOIN instance_of sex))
# (AND (JOIN sex_or_gender male) (JOIN instance_of common_name))
#
# predicted_cores:
# (AND (JOIN (R sex_or_gender) (JOIN instance_of common_name)) (JOIN instance_of sex))
# (AND (JOIN sex_or_gender male) (JOIN instance_of common_name))
#
# calibrated cores:
# (AND (JOIN (R sex_or_gender) (JOIN instance_of common_name)) (JOIN instance_of sex))
# (AND (JOIN sex_or_gender male) (JOIN instance_of common_name))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN continent (JOIN instance_of geographic_location)) (JOIN instance_of administrative_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R located_in_or_next_to_body_of_water) (JOIN instance_of geographic_location)) (JOIN instance_of designation_for_an_administrative_territorial_entity))
# (AND (JOIN located_in_or_next_to_body_of_water Cairo) (JOIN instance_of geographic_location))
#
# calibrated cores:
# (AND (JOIN (R located_in_or_next_to_body_of_water) (JOIN instance_of geographic_location)) (JOIN instance_of protected_area))
# (AND (JOIN (R located_in_or_next_to_body_of_water) Cairo) (JOIN instance_of watercourse))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R inspired_by) (JOIN instance_of fictional_location)) (JOIN instance_of designation_for_an_administrative_territorial_entity))
# (AND (JOIN inspired_by France) (JOIN instance_of fictional_location))
#
# predicted_cores:
# (AND (JOIN (R inspired_by) (JOIN instance_of fictional_location)) (JOIN instance_of designation_for_an_administrative_territorial_entity))
# (AND (JOIN inspired_by France) (JOIN instance_of fictional_location))
#
# calibrated cores:
# (AND (JOIN (R inspired_by) (JOIN instance_of fictional_location)) (JOIN instance_of designation_for_an_administrative_territorial_entity))
# (AND (JOIN inspired_by France) (JOIN instance_of fictional_location))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R sex_or_gender) (JOIN instance_of common_name)) (JOIN instance_of sex))
#
# predicted_cores:
# (AND (JOIN (R sex_or_gender) (JOIN instance_of common_name)) (JOIN instance_of sex))
# (AND (JOIN sex_or_gender male) (JOIN instance_of common_name))
#
# calibrated cores:
# (AND (JOIN (R sex_or_gender) (JOIN instance_of common_name)) (JOIN instance_of sex))
# (AND (JOIN sex_or_gender male) (JOIN instance_of common_name))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R country_of_origin) (JOIN instance_of release)) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R country_of_origin) (JOIN instance_of release)) (JOIN instance_of designation_for_an_administrative_territorial_entity))
# (AND (JOIN country_of_origin Italy) (JOIN instance_of release))
#
# calibrated cores:
# (AND (JOIN (R country_of_origin) (JOIN instance_of release)) (JOIN instance_of designation_for_an_administrative_territorial_entity))
# (AND (JOIN country_of_origin Italy) (JOIN instance_of release))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R native_language) (JOIN instance_of common_name)) (JOIN instance_of language))
# (AND (JOIN native_language English) (JOIN instance_of common_name))
#
# predicted_cores:
# (AND (JOIN (R native_language) (JOIN instance_of common_name)) (JOIN instance_of language))
# (AND (JOIN native_language English) (JOIN instance_of common_name))
#
# calibrated cores:
# (AND (JOIN (R native_language) (JOIN instance_of common_name)) (JOIN instance_of language))
# (AND (JOIN native_language English) (JOIN instance_of common_name))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN located_in/on_physical_feature (JOIN instance_of geographic_region)) (JOIN instance_of geographic_location))
#
# predicted_cores:
# (AND (JOIN located_in (JOIN instance_of geographic_region)) (JOIN instance_of geographic_location))
# (AND (JOIN located_in Southern_Europe) (JOIN instance_of geographic_region))
#
# calibrated cores:
# (AND (JOIN located_in_time_zone (JOIN instance_of technical_standard)) (JOIN instance_of geographic_location))
# (AND (JOIN located_in/on_physical_feature Southern_Europe) (JOIN instance_of concept))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R biological_process) (JOIN instance_of nutrient)) (JOIN instance_of biological_process))
# (AND (JOIN biological_process meiosis_I) (JOIN instance_of nutrient))
#
# predicted_cores:
# (AND (JOIN (R involved_in) (JOIN instance_of nutrient)) (JOIN instance_of biological_process))
# (AND (JOIN involved_in meiosis_I_spindle_assembly_checkpoint) (JOIN instance_of nutrient))
#
# calibrated cores:
# (AND (JOIN (R interested_in) (JOIN instance_of activity)) (JOIN instance_of storage))
# (AND (JOIN (R part_of) meiosis_I_spindle_assembly_checkpoint) (JOIN instance_of biological_process))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN edition_or_translation_of (JOIN instance_of work_of_art)) (JOIN instance_of book))
# (AND (JOIN (R edition_or_translation_of) The_PFA_footballers'_who's_who_2008-09) (JOIN instance_of book))
#
# predicted_cores:
# (AND (JOIN edition_or_translation_of (JOIN instance_of work_of_art)) (JOIN instance_of book))
# (AND (JOIN edition_or_translation_of The_PFA_footballers'_who's_who_2008-09) (JOIN instance_of work_of_art))
#
# calibrated cores:
# (AND (JOIN edition_or_translation_of (JOIN instance_of work_of_art)) (JOIN instance_of book))
# (AND (JOIN edition_or_translation_of The_PFA_footballers'_who's_who_2008-09) (JOIN instance_of book))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R country_of_origin) (JOIN instance_of release)) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R country_of_origin) (JOIN instance_of release)) (JOIN instance_of designation_for_an_administrative_territorial_entity))
# (AND (JOIN country_of_origin Turkey) (JOIN instance_of release))
#
# calibrated cores:
# (AND (JOIN (R country_of_origin) (JOIN instance_of release)) (JOIN instance_of designation_for_an_administrative_territorial_entity))
# (AND (JOIN country_of_origin Turkey) (JOIN instance_of release))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R narrative_location) (JOIN instance_of application)) (JOIN instance_of territorial_entity))
# (AND (JOIN narrative_location England) (JOIN instance_of application))
#
# predicted_cores:
# (AND (JOIN (R narrative_location) (JOIN instance_of application)) (JOIN instance_of territory))
# (AND (JOIN narrative_location England) (JOIN instance_of application))
#
# calibrated cores:
# (AND (JOIN (R narrative_location) (JOIN instance_of application)) (JOIN instance_of territory))
# (AND (JOIN narrative_location England) (JOIN instance_of application))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R found_in_taxon) (JOIN instance_of nucleic_acid_sequence)) (JOIN instance_of infraspecific_name))
# (AND (JOIN found_in_taxon Staphylococcus_epidermidis_ATCC_12228) (JOIN instance_of nucleic_acid_sequence))
#
# predicted_cores:
# (AND (JOIN (R found_in_taxon) (JOIN instance_of nucleic_acid_sequence)) (JOIN instance_of infraspecific_name))
# (AND (JOIN found_in_taxon Staphylococcus_epidermidis_ATCC_12228) (JOIN instance_of nucleic_acid_sequence))
#
# calibrated cores:
# (AND (JOIN (R found_in_taxon) (JOIN instance_of nucleic_acid_sequence)) (JOIN instance_of infraspecific_name))
# (AND (JOIN found_in_taxon Staphylococcus_epidermidis_ATCC_12228) (JOIN instance_of nucleic_acid_sequence))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R cell_component) (JOIN instance_of nutrient)) (JOIN instance_of cellular_component))
# (AND (JOIN cell_component intracellular) (JOIN instance_of nutrient))
#
# predicted_cores:
# (AND (JOIN (R component_of) (JOIN instance_of nutrient)) (JOIN instance_of cellular_component))
# (AND (JOIN component_of intracellular) (JOIN instance_of nutrient))
#
# calibrated cores:
# (AND (JOIN (R part_of) (JOIN instance_of nutrient)) (JOIN instance_of chemical_substance))
# (AND (JOIN part_of intracellular) (JOIN instance_of part_of_a_plant))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R writing_system) (JOIN instance_of language)) (JOIN instance_of alphabet))
# (AND (JOIN writing_system Italian_alphabet) (JOIN instance_of language))
#
# predicted_cores:
# (AND (JOIN (R writing_system) (JOIN instance_of language)) (JOIN instance_of alphabet))
# (AND (JOIN writing_system Italian_alphabet) (JOIN instance_of language))
#
# calibrated cores:
# (AND (JOIN (R writing_system) (JOIN instance_of language)) (JOIN instance_of alphabet))
# (AND (JOIN writing_system Italian_alphabet) (JOIN instance_of language))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R sex_or_gender) (JOIN instance_of common_name)) (JOIN instance_of sex))
#
# predicted_cores:
# (AND (JOIN (R sex_or_gender) (JOIN instance_of common_name)) (JOIN instance_of sex))
# (AND (JOIN sex_or_gender male) (JOIN instance_of common_name))
#
# calibrated cores:
# (AND (JOIN (R sex_or_gender) (JOIN instance_of common_name)) (JOIN instance_of sex))
# (AND (JOIN sex_or_gender male) (JOIN instance_of common_name))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R manner_of_death) (JOIN instance_of common_name)) (JOIN instance_of cause_of_death))
# (AND (JOIN manner_of_death natural_causes) (JOIN instance_of common_name))
#
# predicted_cores:
# (AND (JOIN (R cause_of_death) (JOIN instance_of common_name)) (JOIN instance_of cause_of_death))
# (AND (JOIN cause_of_death natural_causes) (JOIN instance_of common_name))
#
# calibrated cores:
# (AND (JOIN (R cause_of_death) (JOIN instance_of common_name)) (JOIN instance_of cause_of_death))
# (AND (JOIN cause_of_death natural_causes) (JOIN instance_of common_name))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R physically_interacts_with) (JOIN instance_of nutrient)) (JOIN instance_of nutrient))
# (AND (JOIN (R physically_interacts_with) 5-hydroxytryptamine_receptor_2A) (JOIN instance_of nutrient))
#
# predicted_cores:
# (AND (JOIN interacts_with (JOIN instance_of nutrient)) (JOIN instance_of nutrient))
# (AND (JOIN (R interacts_with) 5-hydroxytryptamine_receptor_2A) (JOIN instance_of nutrient))
#
# calibrated cores:
# (AND (JOIN physically_interacts_with (JOIN instance_of nutrient)) (JOIN instance_of nutrient))
# (AND (JOIN (R physically_interacts_with) 5-hydroxytryptamine_receptor_2A) (JOIN instance_of chemical_substance))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R country_of_origin) (JOIN instance_of release)) (JOIN instance_of designation_for_an_administrative_territorial_entity))
#
# predicted_cores:
# (AND (JOIN (R country_of_origin) (JOIN instance_of release)) (JOIN instance_of designation_for_an_administrative_territorial_entity))
# (AND (JOIN country_of_origin Portugal) (JOIN instance_of release))
#
# calibrated cores:
# (AND (JOIN (R country_of_origin) (JOIN instance_of release)) (JOIN instance_of designation_for_an_administrative_territorial_entity))
# (AND (JOIN country_of_origin Portugal) (JOIN instance_of publication))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R country_of_origin) (JOIN instance_of release)) (JOIN instance_of designation_for_an_administrative_territorial_entity))
# (AND (JOIN country_of_origin United_Kingdom) (JOIN instance_of release))
#
# predicted_cores:
# (AND (JOIN (R country_of_origin) (JOIN instance_of release)) (JOIN instance_of designation_for_an_administrative_territorial_entity))
# (AND (JOIN country_of_origin United_Kingdom) (JOIN instance_of release))
#
# calibrated cores:
# (AND (JOIN (R country_of_origin) (JOIN instance_of release)) (JOIN instance_of designation_for_an_administrative_territorial_entity))
# (AND (JOIN country_of_origin United_Kingdom) (JOIN instance_of release))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R ethnic_group) (JOIN instance_of common_name)) (JOIN instance_of people))
#
# predicted_cores:
# (AND (JOIN (R member_of) (JOIN instance_of common_name)) (JOIN instance_of common_name))
# (AND (JOIN member_of Catalan_people) (JOIN instance_of common_name))
#
# calibrated cores:
# (AND (JOIN (R member_of) (JOIN instance_of common_name)) (JOIN instance_of common_name))
# (AND (JOIN member_of Catalan_people) (JOIN instance_of common_name))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN headquarters_location Hamburg) (JOIN instance_of organization))
# (JOIN headquarters_location Dublin)
#
# predicted_cores:
# (AND (JOIN headquarters_location Hamburg) (JOIN instance_of organization))
# (JOIN headquarters_location Dublin)
#
# calibrated cores:
# (AND (JOIN headquarters_location Hamburg) (JOIN instance_of organization))
# (JOIN headquarters_location Dublin)
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R occupation) David_Walker) (JOIN instance_of occupation))
# (JOIN (R occupation) Najm_Sheikh)
#
# predicted_cores:
# (AND (JOIN (R occupation) David_Walker) (JOIN instance_of occupation))
#
# calibrated cores:
# (AND (JOIN (R occupation) David_Walker) (JOIN instance_of occupation))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R molecular_function) exonuclease_V_subunit_beta____O3K_05410) (JOIN instance_of chemical_bond))
# (JOIN (R molecular_function) hypothetical_protein____FTT_0554)
#
# predicted_cores:
# (AND (JOIN (R molecular_function) exonuclease_V_subunit_beta_O3K_05410) (JOIN instance_of chemical_bond))
#
# calibrated cores:
# (AND (JOIN (R molecular_function) exonuclease_V_subunit_beta____O3K_05410) (JOIN instance_of chemical_bond))
#
# --------------------------------
#
# gold cores:
# (AND (JOIN (R twinned_administrative_body) Marseille) (JOIN instance_of administrative_territorial_entity))
# (JOIN (R twinned_administrative_body) Bologna)
#
# predicted_cores:
# (AND (JOIN twinned_administrative_body Marseille) (JOIN instance_of designation_for_an_administrative_territorial_entity))
# (JOIN twinned_administrative_body Bologna)
#
# calibrated cores:
# (AND (JOIN twinned_administrative_body Marseille) (JOIN instance_of administrative_territorial_entity))
# (JOIN twinned_administrative_body Bologna)
#
# --------------------------------
